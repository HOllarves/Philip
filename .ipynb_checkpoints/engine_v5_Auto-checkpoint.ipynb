# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential, load_model
from scipy import stats
from keras.layers import Dense
from keras.layers import LSTM
import numpy as np
from pytz import timezone
from collections import deque
import MySQLdb
import time
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.offline as py
import Queue
est = timezone('US/Eastern')
# Out:
# Using TensorFlow backend.

# %%
btc = pd.read_csv('binance-data.csv')
twitter_sent = pd.read_csv('live_tweet.csv')
reddit_sent = pd.read_csv('live_reddit.csv')

btc.columns = ["Price","Volume", "Number_Trades", "Market_Cap","Supply", "Stamp"]
twitter_sent.columns = ["Sentiment", "Stamp"]
reddit_sent.columns = ["Sentiment", "Stamp"]

merged = pd.merge(twitter_sent, btc,  on='Stamp', how='inner').merge(reddit_sent, on='Stamp', how='inner')
data = merged[["Sentiment_x", "Sentiment_y","Volume", "Market_Cap", "Supply", "Number_Trades", "Price"]].groupby(merged['Stamp']).mean()
datag = data[["Volume", "Market_Cap", "Supply", "Number_Trades", "Price"]]
tw_sentiment = data["Sentiment_x"]
rdt_sentiment = data["Sentiment_y"]

print "Dataset size: " + str(len(datag))
print "Timespan: " + str(len(datag)/60) + " hours"

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
values = datag.values.reshape(-1, datag.shape[1])
tw_sentiment = tw_sentiment.values.reshape(-1, 1)
rdt_sentiment = rdt_sentiment.values.reshape(-1, 1)
tw_sentiment = tw_sentiment.astype('float32')
rdt_sentiment = rdt_sentiment.astype('float32')
values = values.astype('float32')
scaled = scaler.fit_transform(values)
# Out:
# Dataset size: 11263
# Timespan: 187 hours

# %%
train_size = int(len(scaled) * 0.7)
test_size = len(scaled) - train_size
train, test = scaled[0:train_size,:], scaled[train_size:len(scaled),:]
split = train_size

def create_dataset(dataset, look_back, tw_sentiment, rdt_sentiment, sent=False):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        if i >= look_back:
            a = dataset[i-look_back:i+1, 0]
            a = a.tolist()
            if(sent==True):                
                current_tw_sentiment = tw_sentiment[i].tolist()[0]
                current_rdt_sentiment = rdt_sentiment[i].tolist()[0]
                a.append(current_tw_sentiment)
                a.append(current_rdt_sentiment)
            dataX.append(a)
            dataY.append(dataset[i + look_back, 0])
    print(len(dataY))
    return np.array(dataX), np.array(dataY)

look_back = 2
trainX, trainY = create_dataset(train, look_back, tw_sentiment[0:train_size], rdt_sentiment[0:train_size], sent=True)
testX, testY = create_dataset(test, look_back, tw_sentiment[train_size:len(scaled)], rdt_sentiment[train_size:len(scaled)], sent=True)

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# Creating new model
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(100))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
model.save('models/LSTM_Philip_V5_{0}'.format(datetime.now()) + '.h5')

# Loading model
# model = load_model('models/LSTM_12-03-2018_GOOD.h5')

history = model.fit(trainX, trainY, epochs=300, batch_size=100, validation_data=(testX, testY), verbose=0, shuffle=False)
yhat = model.predict(testX)
# yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))
# testY_inverse = scaler.inverse_transform(testY.reshape(-1, 1))
# rmse_sent = sqrt(mean_squared_error(testY_inverse, yhat_inverse))
print "Done"
# print 'Test RMSE: %.3f' % rmse_sent

pyplot.title("Loss")
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# 7880
# 3375
# Done

# %%
#Enter the values for you database connection
dsn_database = "ai_datasets_v5" # e.g. "MySQLdbtest"
dsn_hostname = "127.0.0.1"      # e.g.: "mydbinstance.xyz.us-east-1.rds.amazonaws.com"
dsn_port = 3306                 # e.g. 3306 
dsn_uid = "root"                # e.g. "user1"
dsn_pwd = ""                    # e.g. "Password123"

# %%
true_q = Queue.Queue()
pred_q = Queue.Queue()

def process_data(in_data):
    out_data = []
    for line in in_data:
        out_data.append(float(line.split(',')[0]))
    return np.array(out_data).reshape(-1,1)

def get_last_trade():
    conn = MySQLdb.connect(host=dsn_hostname, port=dsn_port, user=dsn_uid, passwd=dsn_pwd, db=dsn_database)
    cursor = conn.cursor()
    cursor.execute ("select * from trades order by date desc limit 1")
    return cursor.fetchone()

# %%
diffs = deque([], maxlen=200)
lows = []
tops = []
last_trade = ()
top_lows = deque([], maxlen=30)
top_tops = deque([], maxlen=30)
bought = False
to_db = False
prev = 8515
in_cooldown = False
minute_ = 0
status = 0
current_decision = 0

while True:
    
    # Processing data
    minute_ = minute_ + 1
    btc = open('binance-data.csv','r')
    tw_sent = open('live_tweet.csv','r')
    rdt_sent = open('live_reddit.csv','r')
    bit_data = btc.readlines()
    tw_sent_data = tw_sent.readlines()
    rdt_sent_data = rdt_sent.readlines()
    bit_data = process_data(bit_data[len(bit_data)-5:])
    tw_sent_data = process_data(tw_sent_data[len(tw_sent_data)-5:])
    rdt_sent_data = process_data(rdt_sent_data[len(rdt_sent_data)-5:])
    
    # Last price recieved
    real_price = bit_data[len(bit_data) - 1][0]
    
    # Scaling prices
    live = scaler.fit_transform(bit_data)
    
    # Creating datasets and making prediction
    testX, testY = create_dataset(live, 2, tw_sent_data, rdt_sent_data, sent=True)
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
    yhat = model.predict(testX)
    
    #Re scaling prices
    yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))
    
    # Save real price and prediction price
    true_q.put(bit_data[4])
    pred_q.put(yhat_inverse[0])
    
    # Diference between real price and prediction
    alpha_diff = 100 * ((yhat_inverse[0][0] - float(real_price))/float(real_price))
    diffs.append(alpha_diff)
    diff_analisis = stats.describe(diffs)
    
    print "#######################################"
    print "In Cooldown ", in_cooldown
    print "#######################################"
    print "Minute: ", minute_
    print "#######################################"
    print "Diff analysis ", diff_analisis
    print "#######################################"
    print "########---> Initial values <---#######"
    print "#######################################"
    print "Pred: " + str(yhat_inverse[0][0])
    print "Real price: " + str(real_price)
    print "Diff: " + str(alpha_diff)

    if(len(diffs) >= 200):
        
        # Sorting all diffs
        sorted_diffs = sorted(diffs)
        # Taking the highest 75 (most negative)
        tops = sorted_diffs[0:75]
        # Taking the lowest 75 (most positive)
        lows = sorted_diffs[-75:]
        # Analyzing lists
        low_analisis = stats.describe(lows)
        top_analisis = stats.describe(tops)
        
        # Getting averages of tops and lows
        top_threshold = top_analisis.mean
        low_threshold = low_analisis.mean
        
        print "#######################################"
        print "######---> Averages (Phase 2) <---#####"
        print "#######################################"
        print "Average low: " + str(low_threshold)
        print "Average top: " + str(top_threshold)
        print "#######################################"
        print "#######################################"
        print "Top analysis", top_analisis
        print "#######################################"
        print "#######################################"
        print "Low analysis", low_analisis
        print "#######################################"
        print "#######################################"
        print "Low length", len(top_lows)
        print "Top length", len(top_tops)
        print "#######################################"
        print "#######################################"
        print "Low break: ", alpha_diff > low_threshold
        print "#######################################"
        print "Top break: ", alpha_diff < top_threshold 
        
        # If diff is greater than the average low
        if(alpha_diff > low_threshold):
            # Adding to top_lows list
            top_lows.append(alpha_diff)
            # Sorting
            sorted_lows = sorted(top_lows)
            top_lows = deque(sorted_lows, maxlen=30)
            
        # If diff is lower than the average high
        if(alpha_diff < top_threshold):
            # Adding to top_tops list
            top_tops.append(alpha_diff)            
            # Sorting 
            sorted_tops = sorted(top_tops)
            top_tops = deque(sorted_tops, maxlen=30)
             
        if(len(top_tops) >= 30 and len(top_lows) >= 30):
            # Analyzing top_tops and top_lows
            alpha_top_analisis = stats.describe(top_tops)
            alpha_low_analisis = stats.describe(top_lows)

            # Getting averages of top_tops and top_lows analisis
            alpha_top = alpha_top_analisis.mean
            alpha_low = alpha_low_analisis.mean

            print "####################################"
            print "####---> Signals (Phase 3) <---#####"
            print "Buy: " + str(alpha_top - alpha_top_analisis.variance)
            print "####################################"
            print "Sell: " + str(alpha_low)

            if(not in_cooldown):
                if bought:
                    status = ((real_price - buy_price) / buy_price) * 100
                    print "####################################"
                    print "Current status"
                    print "####################################"
                    print "Status", status
                    print "####################################"
                    if status >= 0.15:
                        alpha_low = 0.10
                # If difference is lower that than the lowest top (negative value) -> BUY
                if alpha_diff < alpha_top - alpha_top_analisis.variance  and not bought:
                    decision = 1
                    print "Buy at: " + str(real_price)
                    bought = True
                    to_db = True
                    in_cooldown = True
                    buy_price = real_price
                # If difference is greater than the average low in the top_lows list -> SELL
                elif alpha_diff > alpha_low and bought and status >= 0.10:
                    decision = 2
                    print "Sell at: " + str(real_price)
                    bought = False
                    to_db = True
                    in_cooldown = True
                    buy_price = 0
                else:
                    to_db = False
                    # Saving decision to DB
                if to_db == True:
                    conn = MySQLdb.connect(host=dsn_hostname, port=dsn_port, user=dsn_uid, passwd=dsn_pwd, db=dsn_database)
                    cursor=conn.cursor()
                    input_string = "INSERT INTO live_data (yhat, bit_data, sent_data, reddit_sent, date, decision) values ({},{},{},{},'{}',{});".format(
                        yhat_inverse[0][0],
                        bit_data[0][0],
                        tw_sent_data[4][0],
                        rdt_sent_data[4][0],
                        datetime.now(tz=est).strftime('%Y-%m-%d %H:%M:%S'),
                        decision)
                    cursor.execute(input_string)
                    current_decision = cursor.lastrowid
                    conn.commit()
                    cursor.close()
                    to_db = False
            else:
                last_trade = get_last_trade()
                if len(last_trade) is not 0 and current_decision == last_trade[3]:
                    in_cooldown = False
                print "####################################"
                print "In Cooldown"
                print "####################################"
                print "Last trade", last_trade
                print "####################################"
                print "Current decision", current_decision
                print "####################################"
    time.sleep(60)
# Out:
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1
# #######################################
# Diff analysis  DescribeResult(nobs=1, minmax=(-0.07535061191284663, -0.07535061191284663), mean=-0.07535061191284663, variance=nan, skewness=0.0, kurtosis=-3.0)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8828.34
# Real price: 8835.0
# Diff: -0.0753506119128
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  2
# #######################################
# Diff analysis  DescribeResult(nobs=2, minmax=(-0.07535061191284663, 0.030531405754417758), mean=-0.022409603079214434, variance=0.0056055008326454433, skewness=-1.8267269801791341e-16, kurtosis=-2.0)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8830.7
# Real price: 8828.0
# Diff: 0.0305314057544
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  3
# #######################################
# Diff analysis  DescribeResult(nobs=3, minmax=(-0.33840205276523705, 0.030531405754417758), mean=-0.12774041964122199, variance=0.03608649316918057, skewness=-0.46811842053757347, kurtosis=-1.5000000000000004)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8830.02
# Real price: 8860.0
# Diff: -0.338402052765
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  4
# #######################################
# Diff analysis  DescribeResult(nobs=4, minmax=(-0.40158403381844721, 0.030531405754417758), mean=-0.1962013231855283, variance=0.042805243369198297, skewness=0.08179040950734665, kurtosis=-1.7764485156444139)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8829.09
# Real price: 8864.69
# Diff: -0.401584033818
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  5
# #######################################
# Diff analysis  DescribeResult(nobs=5, minmax=(-0.44791174350691904, 0.030531405754417758), mean=-0.24654340724980645, variance=0.044775559666572956, skewness=0.4018320784724724, kurtosis=-1.5900064468377957)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8836.23
# Real price: 8875.99
# Diff: -0.447911743507
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  6
# #######################################
# Diff analysis  DescribeResult(nobs=6, minmax=(-0.44791174350691904, 0.030531405754417758), mean=-0.25261482617491388, variance=0.036041620499843288, skewness=0.5397337921185191, kurtosis=-1.2601160023645988)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8844.9
# Real price: 8870.0
# Diff: -0.2829719208
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  7
# #######################################
# Diff analysis  DescribeResult(nobs=7, minmax=(-0.44791174350691904, 0.030531405754417758), mean=-0.22360747326661437, variance=0.035924669409095826, skewness=0.16655925452145162, kurtosis=-1.5998967117657674)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8863.59
# Real price: 8867.99
# Diff: -0.0495633558168
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  8
# #######################################
# Diff analysis  DescribeResult(nobs=8, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.18420986457798966, variance=0.04320994634228096, skewness=0.02330622709923857, kurtosis=-1.5913837776847992)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8870.12
# Real price: 8862.0
# Diff: 0.0915733962424
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  9
# #######################################
# Diff analysis  DescribeResult(nobs=9, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.17771779629154635, variance=0.038188025605218431, skewness=-0.077857563437427, kurtosis=-1.441985653257907)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8863.84
# Real price: 8875.0
# Diff: -0.12578125
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  10
# #######################################
# Diff analysis  DescribeResult(nobs=10, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.16979135385996019, variance=0.034573196545295545, skewness=-0.2056654518693114, kurtosis=-1.3022949565098088)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8861.07
# Real price: 8869.8
# Diff: -0.0984533719757
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  11
# #######################################
# Diff analysis  DescribeResult(nobs=11, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.16069850249895234, variance=0.032025356295373189, skewness=-0.34829152325374807, kurtosis=-1.1691567097762712)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8863.3
# Real price: 8869.49
# Diff: -0.0697699888889
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  12
# #######################################
# Diff analysis  DescribeResult(nobs=12, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.16012075527747188, variance=0.029117965770744225, skewness=-0.37430620938981496, kurtosis=-0.9980459665791304)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8866.22
# Real price: 8879.87
# Diff: -0.153765535841
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  13
# #######################################
# Diff analysis  DescribeResult(nobs=13, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.15627481951385583, variance=0.02688375450785439, skewness=-0.45621509729686255, kurtosis=-0.8203739614868439)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8869.2
# Real price: 8878.98
# Diff: -0.11012359035
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  14
# #######################################
# Diff analysis  DescribeResult(nobs=14, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.14254160254387332, variance=0.027456190868690219, skewness=-0.5407685461367502, kurtosis=-0.7907052804111396)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8865.19
# Real price: 8862.0
# Diff: 0.0359902180659
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  15
# #######################################
# Diff analysis  DescribeResult(nobs=15, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.12882757123917238, variance=0.028316154197464249, skewness=-0.5968194251741319, kurtosis=-0.7515098480651496)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8878.58
# Real price: 8872.98
# Diff: 0.0631688670266
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  16
# #######################################
# Diff analysis  DescribeResult(nobs=16, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.1280608446457292, variance=0.026437816499005458, skewness=-0.6306445219284289, kurtosis=-0.5911714546397069)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8859.66
# Real price: 8870.0
# Diff: -0.116559945744
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  17
# #######################################
# Diff analysis  DescribeResult(nobs=17, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.12628210319339139, variance=0.024839239627440116, skewness=-0.6823900901644147, kurtosis=-0.42065966358642815)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8863.28
# Real price: 8871.96
# Diff: -0.097822239956
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  18
# #######################################
# Diff analysis  DescribeResult(nobs=18, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.12050182718524642, variance=0.023979516517795577, skewness=-0.7728499309588112, kurtosis=-0.28162775167772747)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8869.03
# Real price: 8871.0
# Diff: -0.0222371350468
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  19
# #######################################
# Diff analysis  DescribeResult(nobs=19, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.11284624955152131, variance=0.023760870664909669, skewness=-0.8441194865548538, kurtosis=-0.19009876448636343)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8862.21
# Real price: 8860.0
# Diff: 0.0249541478555
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  20
# #######################################
# Diff analysis  DescribeResult(nobs=20, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.10276697054601072, variance=0.024542135830069801, skewness=-0.8440225064379941, kurtosis=-0.1630997808777268)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8867.86
# Real price: 8860.0
# Diff: 0.0887393305587
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  21
# #######################################
# Diff analysis  DescribeResult(nobs=21, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.095414810841860778, variance=0.024450168337188161, skewness=-0.9006710731675465, kurtosis=-0.08187221850693316)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8862.57
# Real price: 8858.0
# Diff: 0.0516283832411
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  22
# #######################################
# Diff analysis  DescribeResult(nobs=22, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.090154879789213285, variance=0.023894545849775187, skewness=-0.9709467117883733, kurtosis=0.04697582840329062)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8851.8
# Real price: 8850.0
# Diff: 0.0203036723164
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  23
# #######################################
# Diff analysis  DescribeResult(nobs=23, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.083900098276621732, variance=0.023708242840046769, skewness=-1.0235610164459015, kurtosis=0.14417503769762963)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8855.24
# Real price: 8850.49
# Diff: 0.0537050950004
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  24
# #######################################
# Diff analysis  DescribeResult(nobs=24, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.080978060283457387, variance=0.022882369017892114, skewness=-1.0863409516507543, kurtosis=0.3078820044568449)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8848.78
# Real price: 8850.0
# Diff: -0.0137711864407
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  25
# #######################################
# Diff analysis  DescribeResult(nobs=25, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.080113420434499275, variance=0.021947627027190105, skewness=-1.1250643445948163, kurtosis=0.46645782506808375)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8850.88
# Real price: 8856.14
# Diff: -0.0593620640595
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  26
# #######################################
# Diff analysis  DescribeResult(nobs=26, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.089105687905874129, variance=0.023172104677297897, skewness=-0.9616435399735529, kurtosis=-0.04141010600611539)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8850.13
# Real price: 8878.0
# Diff: -0.31391237469
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  27
# #######################################
# Diff analysis  DescribeResult(nobs=27, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.096166366417413621, variance=0.02362690577018673, skewness=-0.8316632628109489, kurtosis=-0.34208604102168927)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8851.17
# Real price: 8876.0
# Diff: -0.279744007717
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  28
# #######################################
# Diff analysis  DescribeResult(nobs=28, minmax=(-0.44791174350691904, 0.091573396242383212), mean=-0.098417589258763052, variance=0.02289373930598531, skewness=-0.796331155069966, kurtosis=-0.32619194189104617)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8855.88
# Real price: 8870.0
# Diff: -0.159200605975
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  29
# #######################################
# Diff analysis  DescribeResult(nobs=29, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.088404463130500016, variance=0.024983723910297597, skewness=-0.6414678968598, kurtosis=-0.2759629494691893)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8874.03
# Real price: 8857.03
# Diff: 0.191963068461
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  30
# #######################################
# Diff analysis  DescribeResult(nobs=30, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.085792735919862459, variance=0.024326849759936382, skewness=-0.6908715950274855, kurtosis=-0.18164300163140723)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8866.1
# Real price: 8866.99
# Diff: -0.0100526468114
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  31
# #######################################
# Diff analysis  DescribeResult(nobs=31, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.08848463069889588, variance=0.023740589990481512, skewness=-0.6444462801242569, kurtosis=-0.1872591762991882)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8854.99
# Real price: 8870.0
# Diff: -0.16924147407
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  32
# #######################################
# Diff analysis  DescribeResult(nobs=32, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.089291226442412552, variance=0.022995583601108292, skewness=-0.6378180878624874, kurtosis=-0.11571530780799844)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8857.86
# Real price: 8868.0
# Diff: -0.114295694491
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  33
# #######################################
# Diff analysis  DescribeResult(nobs=33, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.089464817280584807, variance=0.022277966028283868, skewness=-0.6441225835061664, kurtosis=-0.028898224147118512)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8863.33
# Real price: 8871.76
# Diff: -0.0950197241021
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  34
# #######################################
# Diff analysis  DescribeResult(nobs=34, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.087955716802503331, variance=0.021680307213239058, skewness=-0.6802189420134942, kurtosis=0.06742544035720766)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8867.62
# Real price: 8871.0
# Diff: -0.0381554010258
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  35
# #######################################
# Diff analysis  DescribeResult(nobs=35, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.089788865346222185, variance=0.021160266294148879, skewness=-0.6486042978823289, kurtosis=0.0896320750249524)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8869.39
# Real price: 8882.9
# Diff: -0.152115915833
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  36
# #######################################
# Diff analysis  DescribeResult(nobs=36, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.093074613038051229, variance=0.020944348221370149, skewness=-0.5863116413220755, kurtosis=0.016990061480620877)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8869.31
# Real price: 8887.8
# Diff: -0.208075782252
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  37
# #######################################
# Diff analysis  DescribeResult(nobs=37, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.094218641977172654, variance=0.02041098645267779, skewness=-0.5686625752176314, kurtosis=0.06745805996171272)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8873.87
# Real price: 8885.9
# Diff: -0.135403683786
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  38
# #######################################
# Diff analysis  DescribeResult(nobs=38, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.092919437862960225, variance=0.019923479560727667, skewness=-0.6003278723298429, kurtosis=0.15240315717084219)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8880.02
# Real price: 8884.0
# Diff: -0.0448488856371
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  39
# #######################################
# Diff analysis  DescribeResult(nobs=39, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.090106494456419689, variance=0.019707770840751902, skewness=-0.6421309067812412, kurtosis=0.1945719349593129)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8885.49
# Real price: 8884.0
# Diff: 0.0167853549921
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  40
# #######################################
# Diff analysis  DescribeResult(nobs=40, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.089835689084034942, variance=0.019205376805285227, skewness=-0.6560868376366678, kurtosis=0.28065425424643164)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8883.71
# Real price: 8890.76
# Diff: -0.079274279561
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  41
# #######################################
# Diff analysis  DescribeResult(nobs=41, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.090109463430329995, variance=0.018728315433253352, skewness=-0.6580116509082454, kurtosis=0.3562128360312986)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8884.01
# Real price: 8893.0
# Diff: -0.101060437282
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  42
# #######################################
# Diff analysis  DescribeResult(nobs=42, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.091941661708022246, variance=0.018412519174163183, skewness=-0.6218540800780465, kurtosis=0.353090011484408)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8885.28
# Real price: 8900.15
# Diff: -0.167061791093
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  43
# #######################################
# Diff analysis  DescribeResult(nobs=43, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.093487483313790073, variance=0.018076877131277553, skewness=-0.5918656803741742, kurtosis=0.3671125623373972)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8886.84
# Real price: 8900.94
# Diff: -0.158411990756
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  44
# #######################################
# Diff analysis  DescribeResult(nobs=44, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.094076847015102952, variance=0.017671768021039206, skewness=-0.5846521385810062, kurtosis=0.42888633608701277)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8893.12
# Real price: 8903.75
# Diff: -0.119419486172
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  45
# #######################################
# Diff analysis  DescribeResult(nobs=45, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.092799385301560539, variance=0.017343572808982452, skewness=-0.615025936582007, kurtosis=0.5015809370233653)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8896.73
# Real price: 8899.99
# Diff: -0.0365910699057
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  46
# #######################################
# Diff analysis  DescribeResult(nobs=46, minmax=(-0.44791174350691904, 0.19196306846086492), mean=-0.089510588839251837, variance=0.017455704459736685, skewness=-0.6372133095635486, kurtosis=0.47765215590353494)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8896.13
# Real price: 8890.93
# Diff: 0.0584852519646
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  47
# #######################################
# Diff analysis  DescribeResult(nobs=47, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.082994069534269549, variance=0.01907208874470917, skewness=-0.4491944348296779, kurtosis=0.4578575078546687)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8889.78
# Real price: 8870.55
# Diff: 0.216765818495
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  48
# #######################################
# Diff analysis  DescribeResult(nobs=48, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.077031902038106295, variance=0.020372576802591986, skewness=-0.351528779180452, kurtosis=0.3645073285668996)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8877.82
# Real price: 8859.82
# Diff: 0.203189970282
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  49
# #######################################
# Diff analysis  DescribeResult(nobs=49, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.071372198824307259, variance=0.021517727902150726, skewness=-0.29179914915293126, kurtosis=0.2598859410066976)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8868.06
# Real price: 8850.33
# Diff: 0.200293555438
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  50
# #######################################
# Diff analysis  DescribeResult(nobs=50, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.067237721074832779, variance=0.021933285911070168, skewness=-0.30625794362187725, kurtosis=0.18104815729537016)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8837.04
# Real price: 8825.1
# Diff: 0.135351688649
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  51
# #######################################
# Diff analysis  DescribeResult(nobs=51, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.068305723235089363, variance=0.021552792252178717, skewness=-0.2870436132663859, kurtosis=0.21880451982425297)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8836.35
# Real price: 8847.12
# Diff: -0.121705831248
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  52
# #######################################
# Diff analysis  DescribeResult(nobs=52, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.073121151883017738, variance=0.022335982841819202, skewness=-0.26217645866133965, kurtosis=0.0542119571572699)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8821.25
# Real price: 8849.45
# Diff: -0.318708012927
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  53
# #######################################
# Diff analysis  DescribeResult(nobs=53, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.078930311760213978, variance=0.023695000649623574, skewness=-0.27628676564534327, kurtosis=-0.07638118373309277)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8829.88
# Real price: 8863.65
# Diff: -0.381006625374
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  54
# #######################################
# Diff analysis  DescribeResult(nobs=54, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.083523143152549731, variance=0.024387006576383333, skewness=-0.24677602377537888, kurtosis=-0.20528235857198007)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8834.67
# Real price: 8863.65
# Diff: -0.326943206946
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  55
# #######################################
# Diff analysis  DescribeResult(nobs=55, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.082561572896432345, variance=0.023986249298147085, skewness=-0.2663126986657847, kurtosis=-0.15888965057362414)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8850.39
# Real price: 8853.1
# Diff: -0.0306367790661
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  56
# #######################################
# Diff analysis  DescribeResult(nobs=56, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.078687747453357451, variance=0.024390500994095624, skewness=-0.28088718105292426, kurtosis=-0.20985709302384103)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8862.19
# Real price: 8850.3
# Diff: 0.134372651916
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  57
# #######################################
# Diff analysis  DescribeResult(nobs=57, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.075129168094518681, variance=0.024676775095516506, skewness=-0.30083139255983, kurtosis=-0.24885167400124963)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8856.98
# Real price: 8846.0
# Diff: 0.124151276
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  58
# #######################################
# Diff analysis  DescribeResult(nobs=58, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.073343091206551553, variance=0.024428873314332161, skewness=-0.32944830628475524, kurtosis=-0.2249926203068675)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8847.52
# Real price: 8845.0
# Diff: 0.0284632914076
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  59
# #######################################
# Diff analysis  DescribeResult(nobs=59, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.071422298630894332, variance=0.024225363046398687, skewness=-0.3584377333047615, kurtosis=-0.20580393956912157)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8845.04
# Real price: 8841.5
# Diff: 0.0399836707572
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  60
# #######################################
# Diff analysis  DescribeResult(nobs=60, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.070694170250660188, variance=0.023846573929017061, skewness=-0.37461744686896686, kurtosis=-0.15892075626001034)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8842.55
# Real price: 8845.0
# Diff: -0.0277345958168
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  61
# #######################################
# Diff analysis  DescribeResult(nobs=61, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.070846228127064842, variance=0.023450541447664494, skewness=-0.3746924089768746, kurtosis=-0.1134232283649701)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8840.9
# Real price: 8847.98
# Diff: -0.0799697007113
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  62
# #######################################
# Diff analysis  DescribeResult(nobs=62, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.070358622301464752, variance=0.02308084742731694, skewness=-0.3869663753396142, kurtosis=-0.06487689653402073)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8842.41
# Real price: 8846.0
# Diff: -0.0406146669399
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  63
# #######################################
# Diff analysis  DescribeResult(nobs=63, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.072062757863598365, variance=0.02289153260950837, skewness=-0.35715371856031014, kurtosis=-0.07785794673028645)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8843.26
# Real price: 8859.0
# Diff: -0.177719162716
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  64
# #######################################
# Diff analysis  DescribeResult(nobs=64, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.075213402477880026, variance=0.02316347488411211, skewness=-0.3198715700920554, kurtosis=-0.17170155017512023)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8846.06
# Real price: 8870.34
# Diff: -0.273704013178
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  65
# #######################################
# Diff analysis  DescribeResult(nobs=65, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.077839999740325183, variance=0.023249981445688347, skewness=-0.2830986504876291, kurtosis=-0.2337719565775327)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8849.42
# Real price: 8871.24
# Diff: -0.245942224537
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  66
# #######################################
# Diff analysis  DescribeResult(nobs=66, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.079767401852357936, variance=0.023137471430943902, skewness=-0.2515062791887485, kurtosis=-0.2566095081701998)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8854.29
# Real price: 8872.48
# Diff: -0.205048539134
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  67
# #######################################
# Diff analysis  DescribeResult(nobs=67, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.079317614565868624, variance=0.022800458358397065, skewness=-0.26206092569580947, kurtosis=-0.21523687830752403)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8867.6
# Real price: 8872.0
# Diff: -0.0496316536576
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  68
# #######################################
# Diff analysis  DescribeResult(nobs=68, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.077785509013734516, variance=0.022619772634520124, skewness=-0.2870108736312857, kurtosis=-0.19878320769793234)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8870.21
# Real price: 8868.0
# Diff: 0.0248655629793
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  69
# #######################################
# Diff analysis  DescribeResult(nobs=69, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.075498990524171361, variance=0.022647872428721471, skewness=-0.31108346922077207, kurtosis=-0.21175381036389318)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8868.11
# Real price: 8861.02
# Diff: 0.0799842667661
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  70
# #######################################
# Diff analysis  DescribeResult(nobs=70, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.073304219737204079, variance=0.022656833710035351, skewness=-0.3349015395337038, kurtosis=-0.2205763899258395)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8866.44
# Real price: 8859.52
# Diff: 0.0781349645635
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  71
# #######################################
# Diff analysis  DescribeResult(nobs=71, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.0711793146728225, variance=0.022653745385851902, skewness=-0.35831910592397487, kurtosis=-0.22630121351531285)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8858.88
# Real price: 8852.01
# Diff: 0.0775640398339
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  72
# #######################################
# Diff analysis  DescribeResult(nobs=72, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.069875415692884385, variance=0.022457089533023077, skewness=-0.38068691485478945, kurtosis=-0.20273390762676158)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8854.02
# Real price: 8852.01
# Diff: 0.0227014118827
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  73
# #######################################
# Diff analysis  DescribeResult(nobs=73, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.070022645383934393, variance=0.022146767902211737, skewness=-0.38029711965612345, kurtosis=-0.16580919752535106)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8850.86
# Real price: 8858.0
# Diff: -0.0806231831395
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  74
# #######################################
# Diff analysis  DescribeResult(nobs=74, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.069232921372672951, variance=0.021889538657022908, skewness=-0.3969554646518598, kurtosis=-0.13038867099626783)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8852.14
# Real price: 8853.17
# Diff: -0.0115830685506
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  75
# #######################################
# Diff analysis  DescribeResult(nobs=75, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.069165231151142301, variance=0.021594077728033467, skewness=-0.40100971149413944, kurtosis=-0.0909601226901402)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8853.32
# Real price: 8859.0
# Diff: -0.0641561547579
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  76
# #######################################
# Diff analysis  DescribeResult(nobs=76, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.068701035555494214, variance=0.021322532985537143, skewness=-0.41262022411791394, kurtosis=-0.05143298587907319)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8853.0
# Real price: 8856.0
# Diff: -0.0338863658819
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  77
# #######################################
# Diff analysis  DescribeResult(nobs=77, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.068191556894451361, variance=0.021061960115957061, skewness=-0.4250741101581721, kurtosis=-0.012298691902052017)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8853.5
# Real price: 8856.11
# Diff: -0.0294711786552
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  78
# #######################################
# Diff analysis  DescribeResult(nobs=78, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.066703505694703874, variance=0.020961143283498636, skewness=-0.4468485426386414, kurtosis=0.00011461612621044281)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8856.21
# Real price: 8851.97
# Diff: 0.0478764366859
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  79
# #######################################
# Diff analysis  DescribeResult(nobs=79, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.065602887689965375, variance=0.020788108116695948, skewness=-0.4668199852431776, kurtosis=0.02637440290620363)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8850.48
# Real price: 8848.69
# Diff: 0.0202453166796
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  80
# #######################################
# Diff analysis  DescribeResult(nobs=80, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.063800182397069485, variance=0.020784947217466633, skewness=-0.48597941813692624, kurtosis=0.024841037454056192)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8851.94
# Real price: 8844.99
# Diff: 0.0786135357417
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  81
# #######################################
# Diff analysis  DescribeResult(nobs=81, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.062377996647316081, variance=0.020688966974099231, skewness=-0.5065973282427274, kurtosis=0.03911253144916094)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8843.54
# Real price: 8839.0
# Diff: 0.051396863333
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  82
# #######################################
# Diff analysis  DescribeResult(nobs=82, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.061232268909326759, variance=0.020541188376807028, skewness=-0.526345081717119, kurtosis=0.063326000846196)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8842.67
# Real price: 8839.88
# Diff: 0.0315716778678
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  83
# #######################################
# Diff analysis  DescribeResult(nobs=83, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.059956706830546068, variance=0.020425731944725228, skewness=-0.5462529776929405, kurtosis=0.08267187952846111)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8839.94
# Real price: 8836.0
# Diff: 0.0446393836295
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  84
# #######################################
# Diff analysis  DescribeResult(nobs=84, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.059052881359306766, variance=0.020248258429291406, skewness=-0.5640716187965387, kurtosis=0.11386324796571534)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8831.72
# Real price: 8830.31
# Diff: 0.0159646327536
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  85
# #######################################
# Diff analysis  DescribeResult(nobs=85, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.058769390936388909, variance=0.02001403891339492, skewness=-0.5731169105143631, kurtosis=0.15338931214705465)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8836.88
# Real price: 8839.97
# Diff: -0.0349561954113
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  86
# #######################################
# Diff analysis  DescribeResult(nobs=86, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.059336671970578375, variance=0.019806255100431453, skewness=-0.563599874523889, kurtosis=0.17251084083900858)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8829.49
# Real price: 8839.0
# Diff: -0.107555559877
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  87
# #######################################
# Diff analysis  DescribeResult(nobs=87, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.059812807712022811, variance=0.019595673164818406, skewness=-0.5560513475057285, kurtosis=0.1953539578087473)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8831.09
# Real price: 8840.0
# Diff: -0.100760481476
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  88
# #######################################
# Diff analysis  DescribeResult(nobs=88, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.06123658820187719, variance=0.019548824819963808, skewness=-0.529193692710668, kurtosis=0.1585527170949259)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8833.62
# Real price: 8850.0
# Diff: -0.185105490819
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  89
# #######################################
# Diff analysis  DescribeResult(nobs=89, minmax=(-0.44791174350691904, 0.21676581849491552), mean=-0.062992111320816752, variance=0.019600964749853993, skewness=-0.4991112015588057, kurtosis=0.09736450844018485)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8839.72
# Real price: 8858.99
# Diff: -0.217478145787
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  90
# ...
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.215143746192
# ####################################
# Sell: 0.323895319825
# ####################################
# Current status
# ####################################
# Status -4.95323017551
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1265
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75231354349736379, 0.42281309493835761), mean=-0.068823783703272828, variance=0.027692089699262054, skewness=-0.5404644231824413, kurtosis=1.8903502638755665)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8498.33
# Real price: 8497.98
# Diff: 0.00406208666648
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0794139802676
# Average top: -0.22897291941
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75231354349736379, -0.097498686124299128), mean=-0.22897291941003545, variance=0.016594026750595282, skewness=-1.5710533362911068, kurtosis=3.0199985685858053)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.003120271952576306, 0.42281309493835761), mean=0.079413980267560122, variance=0.0088704451616053968, skewness=1.8230306657182163, kurtosis=3.2334981662349955)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.215143746192
# ####################################
# Sell: 0.323895319825
# ####################################
# Current status
# ####################################
# Status -4.99604801411
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1266
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75231354349736379, 0.42281309493835761), mean=-0.069299071244004654, variance=0.027683552247635468, skewness=-0.5323816625233518, kurtosis=1.8871685323847025)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8498.84
# Real price: 8508.0
# Diff: -0.107653733986
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0794139802676
# Average top: -0.229108320048
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75231354349736379, -0.097514512453381483), mean=-0.22910832004818696, variance=0.016559317233487185, skewness=-1.5759266679522845, kurtosis=3.0344739624392023)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.003120271952576306, 0.42281309493835761), mean=0.079413980267560122, variance=0.0088704451616053968, skewness=1.8230306657182163, kurtosis=3.2334981662349955)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.215143746192
# ####################################
# Sell: 0.323895319825
# ####################################
# Current status
# ####################################
# Status -4.88402849902
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1267
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75231354349736379, 0.42281309493835761), mean=-0.069729422784119241, variance=0.027687697381923129, skewness=-0.5246650878284369, kurtosis=1.8802449056849904)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8498.02
# Real price: 8508.0
# Diff: -0.117341307446
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0794139802676
# Average top: -0.229372677315
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75231354349736379, -0.10132163357147196), mean=-0.22937267731475425, variance=0.016494042822019682, skewness=-1.5847426279774446, kurtosis=3.0619281901644246)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.003120271952576306, 0.42281309493835761), mean=0.079413980267560122, variance=0.0088704451616053968, skewness=1.8230306657182163, kurtosis=3.2334981662349955)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.215143746192
# ####################################
# Sell: 0.323895319825
# ####################################
# Current status
# ####################################
# Status -4.88402849902
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1268
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75231354349736379, 0.42281309493835761), mean=-0.07028184503564, variance=0.02778638537148681, skewness=-0.5151374367951341, kurtosis=1.8415633226240216)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8501.22
# Real price: 8519.46
# Diff: -0.214124211658
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0794139802676
# Average top: -0.230845803319
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75231354349736379, -0.10132163357147196), mean=-0.23084580331880958, variance=0.016281353525155029, skewness=-1.5940203559361135, kurtosis=3.1335130356864633)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.003120271952576306, 0.42281309493835761), mean=0.079413980267560122, variance=0.0088704451616053968, skewness=1.8230306657182163, kurtosis=3.2334981662349955)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.215143746192
# ####################################
# Sell: 0.323895319825
# ####################################
# Current status
# ####################################
# Status -4.75591037097
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1269
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75231354349736379, 0.42281309493835761), mean=-0.070498742590722932, variance=0.027835980055956364, skewness=-0.5117038469086974, kurtosis=1.8233789269928344)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8501.46
# Real price: 8519.0
# Diff: -0.205835852213
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0794139802676
# Average top: -0.231424196799
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75231354349736379, -0.10132163357147196), mean=-0.23142419679903076, variance=0.016226262831892203, skewness=-1.5904338870645347, kurtosis=3.1449085687255423)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.003120271952576306, 0.42281309493835761), mean=0.079413980267560122, variance=0.0088704451616053968, skewness=1.8230306657182163, kurtosis=3.2334981662349955)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.215143746192
# ####################################
# Sell: 0.323895319825
# ####################################
# Current status
# ####################################
# Status -4.76105298344
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1270
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75231354349736379, 0.42281309493835761), mean=-0.071395093098119658, variance=0.02798802141832029, skewness=-0.4971399373396142, kurtosis=1.7662362345549463)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8510.56
# Real price: 8531.46
# Diff: -0.244969244713
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0794139802676
# Average top: -0.233339498281
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75231354349736379, -0.10269674268391032), mean=-0.23333949828091893, variance=0.015996285303272257, skewness=-1.5939403372755856, kurtosis=3.2089382750186557)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.003120271952576306, 0.42281309493835761), mean=0.079413980267560122, variance=0.0088704451616053968, skewness=1.8230306657182163, kurtosis=3.2334981662349955)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  True
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.210898854447
# ####################################
# Sell: 0.323895319825
# ####################################
# Current status
# ####################################
# Status -4.62175526307
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1271
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75231354349736379, 0.42281309493835761), mean=-0.072712811556597187, variance=0.027885259237373377, skewness=-0.4823523816336057, kurtosis=1.7808770565109828)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8511.93
# Real price: 8526.0
# Diff: -0.165028295801
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0780491810993
# Average top: -0.234170585656
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75231354349736379, -0.10388091314724063), mean=-0.23417058565581453, variance=0.015828002706345348, skewness=-1.6125320094848676, kurtosis=3.283770234301697)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0038445417233191983, 0.42281309493835761), mean=0.078049181099323489, variance=0.0089573021433274769, skewness=1.8307608167643727, kurtosis=3.2264229992777658)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.210898854447
# ####################################
# Sell: 0.323895319825
# ####################################
# Current status
# ####################################
# Status -4.68279583717
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1272
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75231354349736379, 0.42281309493835761), mean=-0.072900161183979004, variance=0.027840757757325002, skewness=-0.48184633052177545, kurtosis=1.7923476946324168)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8520.73
# Real price: 8518.46
# Diff: 0.0266305837558
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.077549582093
# Average top: -0.234170585656
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75231354349736379, -0.10388091314724063), mean=-0.23417058565581453, variance=0.015828002706345348, skewness=-1.6125320094848676, kurtosis=3.283770234301697)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0038445417233191983, 0.42281309493835761), mean=0.077549582092971997, variance=0.0089901479104678092, skewness=1.8345244843213684, kurtosis=3.220944253681272)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.210898854447
# ####################################
# Sell: 0.323895319825
# ####################################
# Current status
# ####################################
# Status -4.7670899633
# ####################################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-004fa638a592> in <module>()
#     186                 print "Current decision", current_decision
#     187                 print "####################################"
# --> 188     time.sleep(60)
#
# KeyboardInterrupt:
