# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential, load_model
from scipy import stats
from keras.layers import Dense
from keras.layers import LSTM
import numpy as np
from pytz import timezone
from collections import deque
import MySQLdb
import time
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.offline as py
import Queue
est = timezone('US/Eastern')

# %%
btc = pd.read_csv('binance-data.csv')
twitter_sent = pd.read_csv('live_tweet.csv')
reddit_sent = pd.read_csv('live_reddit.csv')

btc.columns = ["Price","Volume", "Number_Trades", "Market_Cap","Supply", "Stamp"]
twitter_sent.columns = ["Sentiment", "Stamp"]
reddit_sent.columns = ["Sentiment", "Stamp"]

merged = pd.merge(twitter_sent, btc,  on='Stamp', how='inner').merge(reddit_sent, on='Stamp', how='inner')
data = merged[["Sentiment_x", "Sentiment_y","Volume", "Market_Cap", "Supply", "Number_Trades", "Price"]].groupby(merged['Stamp']).mean()
datag = data[["Volume", "Market_Cap", "Supply", "Number_Trades", "Price"]]
tw_sentiment = data["Sentiment_x"]
rdt_sentiment = data["Sentiment_y"]

print "Dataset size: " + str(len(datag))
print "Timespan: " + str(len(datag)/60) + " hours"

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
values = datag.values.reshape(-1, datag.shape[1])
tw_sentiment = tw_sentiment.values.reshape(-1, 1)
rdt_sentiment = rdt_sentiment.values.reshape(-1, 1)
tw_sentiment = tw_sentiment.astype('float32')
rdt_sentiment = rdt_sentiment.astype('float32')
values = values.astype('float32')
scaled = scaler.fit_transform(values)
# Out:
# Dataset size: 11263
# Timespan: 187 hours

# %%
train_size = int(len(scaled) * 0.7)
test_size = len(scaled) - train_size
train, test = scaled[0:train_size,:], scaled[train_size:len(scaled),:]
split = train_size

def create_dataset(dataset, look_back, tw_sentiment, rdt_sentiment, sent=False):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        if i >= look_back:
            a = dataset[i-look_back:i+1, 0]
            a = a.tolist()
            if(sent==True):                
                current_tw_sentiment = tw_sentiment[i].tolist()[0]
                current_rdt_sentiment = rdt_sentiment[i].tolist()[0]
                a.append(current_tw_sentiment)
                a.append(current_rdt_sentiment)
            dataX.append(a)
            dataY.append(dataset[i + look_back, 0])
    print(len(dataY))
    return np.array(dataX), np.array(dataY)

look_back = 2
trainX, trainY = create_dataset(train, look_back, tw_sentiment[0:train_size], rdt_sentiment[0:train_size], sent=True)
testX, testY = create_dataset(test, look_back, tw_sentiment[train_size:len(scaled)], rdt_sentiment[train_size:len(scaled)], sent=True)

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# Creating new model
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(100))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
model.save('models/LSTM_Philip_V3_{0}'.format(datetime.now()) + '.h5')

# Loading model
# model = load_model('models/LSTM_12-03-2018_GOOD.h5')

history = model.fit(trainX, trainY, epochs=300, batch_size=100, validation_data=(testX, testY), verbose=0, shuffle=False)
yhat = model.predict(testX)
# yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))
# testY_inverse = scaler.inverse_transform(testY.reshape(-1, 1))
# rmse_sent = sqrt(mean_squared_error(testY_inverse, yhat_inverse))
print "Done"
# print 'Test RMSE: %.3f' % rmse_sent

pyplot.title("Loss")
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# 7880
# 3375
# Done

# %%
#Enter the values for you database connection
dsn_database = "ai_datasets"         # e.g. "MySQLdbtest"
dsn_hostname = "127.0.0.1"      # e.g.: "mydbinstance.xyz.us-east-1.rds.amazonaws.com"
dsn_port = 3306                  # e.g. 3306 
dsn_uid = "root"             # e.g. "user1"
dsn_pwd = ""              # e.g. "Password123"

# %%
true_q = Queue.Queue()
pred_q = Queue.Queue()

def process_data(in_data):
    out_data = []
    for line in in_data:
        out_data.append(float(line.split(',')[0]))
    return np.array(out_data).reshape(-1,1)

def get_last_trade():
    conn = MySQLdb.connect(host=dsn_hostname, port=dsn_port, user=dsn_uid, passwd=dsn_pwd, db=dsn_database)
    cursor = conn.cursor()
    cursor.execute ("select * from trades order by date desc limit 1")
    return cursor.fetchone()

# %%
trades = []
diffs = deque([], maxlen=200)
lows = []
tops = []
last_trade = ()
top_lows = deque([], maxlen=30)
top_tops = deque([], maxlen=30)
bought = False
status = 0
to_db = False
prev = 8525
in_cooldown = False
minute_ = 0
current_decision = 0

while True:
    
    # Processing data
    minute_ = minute_ + 1
    btc = open('binance-data.csv','r')
    tw_sent = open('live_tweet.csv','r')
    rdt_sent = open('live_reddit.csv','r')
    bit_data = btc.readlines()
    tw_sent_data = tw_sent.readlines()
    rdt_sent_data = rdt_sent.readlines()
    bit_data = process_data(bit_data[len(bit_data)-5:])
    tw_sent_data = process_data(tw_sent_data[len(tw_sent_data)-5:])
    rdt_sent_data = process_data(rdt_sent_data[len(rdt_sent_data)-5:])
    
    # Last price recieved
    real_price = bit_data[len(bit_data) - 1][0]
    
    # Scaling prices
    live = scaler.fit_transform(bit_data)
    
    # Creating datasets and making prediction
    testX, testY = create_dataset(live, 2, tw_sent_data, rdt_sent_data, sent=True)
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
    yhat = model.predict(testX)
    
    #Re scaling prices
    yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))
    
    # Save real price and prediction price
    true_q.put(bit_data[4])
    pred_q.put(yhat_inverse[0])
    
    # Diference between real price and prediction
    alpha_diff = 100 * ((yhat_inverse[0][0] - float(real_price))/float(real_price))
    diffs.append(alpha_diff)
    diff_analisis = stats.describe(diffs)
    
    print "#######################################"
    print "In Cooldown ", in_cooldown
    print "#######################################"
    print "Minute: ", minute_
    print "#######################################"
    print "Diff analysis ", diff_analisis
    print "#######################################"
    print "########---> Initial values <---#######"
    print "#######################################"
    print "Pred: " + str(yhat_inverse[0][0])
    print "Real price: " + str(real_price)
    print "Diff: " + str(alpha_diff)

    
    
    if(len(diffs) >= 200):
        # Sorting all diffs
        sorted_diffs = sorted(diffs)
        # Taking the highest 75 (most negative)
        tops = sorted_diffs[0:75]
        # Taking the lowest 75 (most positive)
        lows = sorted_diffs[-75:]
        # Analyzing lists
        low_analisis = stats.describe(lows)
        top_analisis = stats.describe(tops)
        
        # Getting averages of tops and lows
        top_threshold = top_analisis.mean
        low_threshold = low_analisis.mean
        
        print "#######################################"
        print "########---> Averages (Phase 2) <---############"
        print "#######################################"
        print "Average low: " + str(low_threshold)
        print "Average top: " + str(top_threshold)
        print "#######################################"
        print "#######################################"
        print "Top analysis", top_analisis
        print "#######################################"
        print "#######################################"
        print "Low analysis", low_analisis
        print "#######################################"
        print "#######################################"
        print "Low length", len(top_lows)
        print "Top length", len(top_tops)
        print "#######################################"
        print "#######################################"
        print "Low break: ", alpha_diff > low_threshold
        print "#######################################"
        print "Top break: ", alpha_diff < top_threshold 
        
        # If diff is greater than the average low
        if(alpha_diff > low_threshold):
            # Adding to top_lows list
            top_lows.append(alpha_diff)
            # Sorting
            sorted_lows = sorted(top_lows)
            top_lows = deque(sorted_lows, maxlen=30)
            
        # If diff is lower than the average high
        if(alpha_diff < top_threshold):
            # Adding to top_tops list
            top_tops.append(alpha_diff)            
            # Sorting 
            sorted_tops = sorted(top_tops)
            top_tops = deque(sorted_tops, maxlen=30)
             
        if(len(top_tops) >= 30 and len(top_lows) >= 30):
            # Analyzing top_tops and top_lows
            alpha_top_analisis = stats.describe(top_tops)
            alpha_low_analisis = stats.describe(top_lows)

            # Getting averages of top_tops and top_lows analisis
            alpha_top = alpha_top_analisis.mean
            alpha_low = alpha_low_analisis.mean

            print "####################################"
            print "#######---> Signals (Phase 3) <---#######"
            print "Buy: " + str(alpha_top - alpha_top_analisis.variance)
            print "####################################"
            print "Sell: " + str(alpha_low)
            
            if(not in_cooldown):
                # If difference is lower that than the lowest top (negative value) -> BUY
                if alpha_diff < alpha_top - alpha_top_analisis.variance  and not bought:
                    decision = 1
                    print "Buy at: " + str(real_price)
                    bought = True
                    trades.append(("Buy", str(real_price)))
                    to_db = True
                    in_cooldown = True
                # If difference is greater than the average low in the top_lows list -> SELL
                elif alpha_diff > alpha_low and bought:
                    decision = 2
                    print "Sell at: " + str(real_price)
                    bought = False
                    trades.append(("Sold", str(real_price)))
                    to_db = True
                    in_cooldown = True
                else:
                    to_db = False
                    
                    # Saving decision to DB
                if to_db == True:
                    conn = MySQLdb.connect(host=dsn_hostname, port=dsn_port, user=dsn_uid, passwd=dsn_pwd, db=dsn_database)
                    cursor=conn.cursor()
                    input_string = "INSERT INTO live_data (yhat, bit_data, sent_data, reddit_sent, date, decision) values ({},{},{},{},'{}',{});".format(
                        yhat_inverse[0][0],
                        bit_data[0][0],
                        tw_sent_data[4][0],
                        rdt_sent_data[4][0],
                        datetime.now(tz=est).strftime('%Y-%m-%d %H:%M:%S'),
                        decision)
                    cursor.execute(input_string)
                    current_decision = cursor.lastrowid
                    conn.commit()
                    cursor.close()
                    to_db = False
            else:
                last_trade = get_last_trade()
                if len(last_trade) is not 0 and current_decision == last_trade[3]:
                    in_cooldown = False
                print "####################################"
                print "In Cooldown"
                print "####################################"
                print "Last trade", last_trade
                print "####################################"
                print "Current decision", current_decision
                print "####################################"

    time.sleep(60)
# Out:
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1
# #######################################
# Diff analysis  DescribeResult(nobs=1, minmax=(-0.053087265970076444, -0.053087265970076444), mean=-0.053087265970076444, variance=nan, skewness=0.0, kurtosis=-3.0)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8863.28
# Real price: 8867.99
# Diff: -0.0530872659701
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  2
# #######################################
# Diff analysis  DescribeResult(nobs=2, minmax=(-0.053087265970076444, 0.091077511425186178), mean=0.018995122727554867, variance=0.010391741520712813, skewness=0.0, kurtosis=-2.0)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8870.07
# Real price: 8862.0
# Diff: 0.0910775114252
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  3
# #######################################
# Diff analysis  DescribeResult(nobs=3, minmax=(-0.11812279929577464, 0.091077511425186178), mean=-0.026710851280221635, variance=0.011462978940355029, skewness=0.4251202162048458, kurtosis=-1.4999999999999998)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8864.52
# Real price: 8875.0
# Diff: -0.118122799296
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  4
# #######################################
# Diff analysis  DescribeResult(nobs=4, minmax=(-0.11812279929577464, 0.091077511425186178), mean=-0.040718673928833146, variance=0.0084268623416565019, skewness=0.8704725455962025, kurtosis=-0.8672529811245857)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8862.46
# Real price: 8869.8
# Diff: -0.0827421418747
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  5
# #######################################
# Diff analysis  DescribeResult(nobs=5, minmax=(-0.11812279929577464, 0.091077511425186178), mean=-0.047403159254932659, variance=0.0065435584766165731, skewness=1.1820422716523453, kurtosis=-0.1183531801736728)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8862.91
# Real price: 8869.49
# Diff: -0.0741411005593
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  6
# #######################################
# Diff analysis  DescribeResult(nobs=6, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.064761806223243776, variance=0.0070427825287160007, skewness=1.1023747856261001, kurtosis=0.16828932946953534)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8866.41
# Real price: 8879.87
# Diff: -0.151555041065
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  7
# #######################################
# Diff analysis  DescribeResult(nobs=7, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.070690560431495811, variance=0.0061150363258297294, skewness=1.3388764718073853, kurtosis=0.8185752542456619)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8869.54
# Real price: 8878.98
# Diff: -0.106263085681
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  8
# #######################################
# Diff analysis  DescribeResult(nobs=8, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.056573067074410559, variance=0.0068358886573528232, skewness=0.796565520959028, kurtosis=-0.6484869548694752)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8865.74
# Real price: 8862.0
# Diff: 0.0422493864252
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  9
# #######################################
# Diff analysis  DescribeResult(nobs=9, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.043975239187700986, variance=0.0074097499823521382, skewness=0.44631195391498285, kurtosis=-1.2751670528079553)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8878.02
# Real price: 8872.98
# Diff: 0.056807383906
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  10
# #######################################
# Diff analysis  DescribeResult(nobs=10, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.050418990283023338, variance=0.0070016637105421347, skewness=0.619801389639347, kurtosis=-1.0989988797392913)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8860.38
# Real price: 8870.0
# Diff: -0.108412750141
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  11
# #######################################
# Diff analysis  DescribeResult(nobs=11, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.055110629831243908, variance=0.0065436236376426229, skewness=0.7697872220306207, kurtosis=-0.8774746041348243)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8862.91
# Real price: 8871.96
# Diff: -0.102027025313
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  12
# #######################################
# Diff analysis  DescribeResult(nobs=12, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.05250052160422173, variance=0.0060305007409745199, skewness=0.6885927386517738, kurtosis=-0.8483367004609472)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8868.89
# Real price: 8871.0
# Diff: -0.023789331107
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  13
# #######################################
# Diff analysis  DescribeResult(nobs=13, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.045648828090474512, variance=0.0061382531646422094, skewness=0.46615286202745204, kurtosis=-1.1781875395103496)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8863.24
# Real price: 8860.0
# Diff: 0.0365714940745
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  14
# #######################################
# Diff analysis  DescribeResult(nobs=14, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.036184301591912722, variance=0.0069201615100728123, skewness=0.32514470127064377, kurtosis=-1.3888703442381254)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8867.7
# Real price: 8860.0
# Diff: 0.0868545428894
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  15
# #######################################
# Diff analysis  DescribeResult(nobs=15, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.029850918305609098, variance=0.0070275404171217786, skewness=0.16679433925176296, kurtosis=-1.519403868879752)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8863.21
# Real price: 8858.0
# Diff: 0.0588164477026
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  16
# #######################################
# Diff analysis  DescribeResult(nobs=16, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.026152112235661069, variance=0.0067779363841363426, skewness=0.05025957180001661, kurtosis=-1.5243235769819206)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8852.6
# Real price: 8850.0
# Diff: 0.0293299788136
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  17
# #######################################
# Diff analysis  DescribeResult(nobs=17, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.021373497151201352, variance=0.0067425131162600627, skewness=-0.07039613869202328, kurtosis=-1.5485353720878563)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8855.37
# Real price: 8850.49
# Diff: 0.0550843442002
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  18
# #######################################
# Diff analysis  DescribeResult(nobs=18, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.020446619916184832, variance=0.0063613585230147835, skewness=-0.10749479609890492, kurtosis=-1.466214889323118)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8849.58
# Real price: 8850.0
# Diff: -0.0046897069209
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  19
# #######################################
# Diff analysis  DescribeResult(nobs=19, minmax=(-0.15155504106479936, 0.091077511425186178), mean=-0.022379308350990754, variance=0.0060789201233152467, skewness=-0.03805561394889261, kurtosis=-1.4234702589406256)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8851.08
# Real price: 8856.14
# Diff: -0.0571677001775
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  20
# #######################################
# Diff analysis  DescribeResult(nobs=20, minmax=(-0.31395637390177966, 0.091077511425186178), mean=-0.036958161628530203, variance=0.010009836216690686, skewness=-0.9017985016235384, kurtosis=0.871940637445928)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8850.13
# Real price: 8878.0
# Diff: -0.313956373902
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  21
# #######################################
# Diff analysis  DescribeResult(nobs=21, minmax=(-0.31395637390177966, 0.091077511425186178), mean=-0.048501055258946976, variance=0.012307350666481592, skewness=-0.84100254603787, kurtosis=0.19676644467583193)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8851.2
# Real price: 8876.0
# Diff: -0.279358927867
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  22
# #######################################
# Diff analysis  DescribeResult(nobs=22, minmax=(-0.31395637390177966, 0.091077511425186178), mean=-0.053986753904038398, variance=0.012383329920774762, skewness=-0.70336846882513, kurtosis=-0.08775168351801277)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8854.99
# Real price: 8870.0
# Diff: -0.169186425451
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  23
# #######################################
# Diff analysis  DescribeResult(nobs=23, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.043585707981339414, variance=0.014308631682592415, skewness=-0.4356681470931395, kurtosis=-0.05458478382751775)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8873.44
# Real price: 8857.03
# Diff: 0.185237302318
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  24
# #######################################
# Diff analysis  DescribeResult(nobs=24, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.042030178595035654, variance=0.013744589381729845, skewness=-0.4814500311772834, kurtosis=0.07302593853142136)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8866.44
# Real price: 8866.99
# Diff: -0.00625300271005
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  25
# #######################################
# Diff analysis  DescribeResult(nobs=25, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.046149774720681797, variance=0.013596174963452072, skewness=-0.3896375104454658, kurtosis=-0.03318341292085991)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8857.14
# Real price: 8870.0
# Diff: -0.145020081736
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  26
# #######################################
# Diff analysis  DescribeResult(nobs=26, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.048838539061470607, variance=0.013240293760601724, skewness=-0.3265670696836238, kurtosis=-0.030363144123993546)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8857.71
# Real price: 8868.0
# Diff: -0.116057647581
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  27
# #######################################
# Diff analysis  DescribeResult(nobs=27, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.050524899809657478, variance=0.01280783463235796, skewness=-0.2867944911402617, kurtosis=0.02923242797430925)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8863.39
# Real price: 8871.76
# Diff: -0.0943702792625
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  28
# #######################################
# Diff analysis  DescribeResult(nobs=28, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.050079200394985791, variance=0.012339032529825754, skewness=-0.30406435150285915, kurtosis=0.14347027614279195)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8867.62
# Real price: 8871.0
# Diff: -0.0380453161989
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  29
# #######################################
# Diff analysis  DescribeResult(nobs=29, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.053591642314820699, variance=0.012256132995583882, skewness=-0.2274064993156041, kurtosis=0.059311359917010975)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8869.4
# Real price: 8882.9
# Diff: -0.15194001607
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  30
# #######################################
# Diff analysis  DescribeResult(nobs=30, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.058782134296091901, variance=0.012641743930103313, skewness=-0.1616703744114456, kurtosis=-0.13930286420539773)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8869.2
# Real price: 8887.8
# Diff: -0.209306401753
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  31
# #######################################
# Diff analysis  DescribeResult(nobs=31, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.06162249474611374, variance=0.012470449537834032, skewness=-0.09845049533472906, kurtosis=-0.16220551858591037)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8872.85
# Real price: 8885.9
# Diff: -0.146833308247
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  32
# #######################################
# Diff analysis  DescribeResult(nobs=32, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.06112511337291307, variance=0.012076093395470477, skewness=-0.11362361660013928, kurtosis=-0.07252533984365828)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8879.94
# Real price: 8884.0
# Diff: -0.0457062908037
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  33
# #######################################
# Diff analysis  DescribeResult(nobs=33, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.058772184542891924, variance=0.011881412521473796, skewness=-0.16703628359646, kurtosis=-0.053110406611290184)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8885.47
# Real price: 8884.0
# Diff: 0.0165215380178
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  34
# #######################################
# Diff analysis  DescribeResult(nobs=34, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.059195889429476949, variance=0.011527473596043917, skewness=-0.1574707243282298, kurtosis=0.030365482624287843)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8884.25
# Real price: 8890.76
# Diff: -0.0731781506868
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  35
# #######################################
# Diff analysis  DescribeResult(nobs=35, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.060410530616939517, variance=0.011240067617483619, skewness=-0.125720222623292, kurtosis=0.08502405530911306)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8883.96
# Real price: 8893.0
# Diff: -0.101708330991
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  36
# #######################################
# Diff analysis  DescribeResult(nobs=36, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.063445910356730445, variance=0.011250609914343058, skewness=-0.06649676995304069, kurtosis=0.009154117879456969)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8885.05
# Real price: 8900.15
# Diff: -0.169684201249
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  37
# #######################################
# Diff analysis  DescribeResult(nobs=37, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.066046365116380831, variance=0.011188300475686539, skewness=-0.011573974487498124, kurtosis=-0.029374276542413646)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8886.73
# Real price: 8900.94
# Diff: -0.159662736464
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  38
# #######################################
# Diff analysis  DescribeResult(nobs=38, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.067626120158520153, variance=0.010980747764083917, skewness=0.02911020520961996, kurtosis=0.001810850547003806)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8892.52
# Real price: 8903.75
# Diff: -0.126077056718
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  39
# #######################################
# Diff analysis  DescribeResult(nobs=39, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.066807278992436298, variance=0.010717930251016325, skewness=0.006126446983286981, kurtosis=0.06545408876142123)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8896.81
# Real price: 8899.99
# Diff: -0.0356913146812
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  40
# #######################################
# Diff analysis  DescribeResult(nobs=40, minmax=(-0.31395637390177966, 0.18523730231803825), mean=-0.063582427153224347, variance=0.010859098302026044, skewness=-0.038946723982408026, kurtosis=-0.031477633323556464)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8896.46
# Real price: 8890.93
# Diff: 0.062186794576
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  41
# #######################################
# Diff analysis  DescribeResult(nobs=41, minmax=(-0.31395637390177966, 0.21758048754023968), mean=-0.05672479508753011, variance=0.012515732663961346, skewness=0.18468634492261377, kurtosis=0.13079381122495182)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8889.85
# Real price: 8870.55
# Diff: 0.21758048754
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  42
# #######################################
# Diff analysis  DescribeResult(nobs=42, minmax=(-0.31395637390177966, 0.21758048754023968), mean=-0.050249504130413951, variance=0.01397150539680064, skewness=0.28689700790353145, kurtosis=0.0677454285656105)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8878.89
# Real price: 8859.82
# Diff: 0.215237425111
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  43
# #######################################
# Diff analysis  DescribeResult(nobs=43, minmax=(-0.31395637390177966, 0.21848893981919401), mean=-0.043999772875771906, variance=0.015318393558876356, skewness=0.33709097816275135, kurtosis=-0.05291510148913625)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8869.67
# Real price: 8850.33
# Diff: 0.218488939819
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  44
# #######################################
# Diff analysis  DescribeResult(nobs=44, minmax=(-0.31395637390177966, 0.21848893981919401), mean=-0.039077577278436575, variance=0.016028184266135618, skewness=0.307264076245736, kurtosis=-0.2260007113684015)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8840.33
# Real price: 8825.1
# Diff: 0.172576833407
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  45
# #######################################
# Diff analysis  DescribeResult(nobs=45, minmax=(-0.31395637390177966, 0.21848893981919401), mean=-0.040408456588460567, variance=0.015743613139199419, skewness=0.3380613425868059, kurtosis=-0.17658779905708455)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8838.36
# Real price: 8847.12
# Diff: -0.0989671462295
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  46
# #######################################
# Diff analysis  DescribeResult(nobs=46, minmax=(-0.31395637390177966, 0.21848893981919401), mean=-0.045591456959997584, variance=0.016629475740601665, skewness=0.2844013580519049, kurtosis=-0.2251068006269854)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8824.78
# Real price: 8849.45
# Diff: -0.278826473679
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  47
# #######################################
# Diff analysis  DescribeResult(nobs=47, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.053163497175447182, variance=0.018962747670560814, skewness=0.01603663404886121, kurtosis=0.06255673207694246)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8828.06
# Real price: 8863.65
# Diff: -0.401477347086
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  48
# #######################################
# Diff analysis  DescribeResult(nobs=48, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.058813530274139623, variance=0.020091582906949266, skewness=-0.015300688296343986, kurtosis=-0.05217277091285322)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8834.9
# Real price: 8863.65
# Diff: -0.324365085913
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  49
# #######################################
# Diff analysis  DescribeResult(nobs=49, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.064224855205432807, variance=0.021107847701144215, skewness=-0.028918853989101594, kurtosis=-0.16287007867354042)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8834.93
# Real price: 8863.65
# Diff: -0.323968451908
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  50
# #######################################
# Diff analysis  DescribeResult(nobs=50, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.063731350451461471, variance=0.020689252646189663, skewness=-0.03948008827339959, kurtosis=-0.10788311038527976)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8849.6
# Real price: 8853.1
# Diff: -0.0395496175069
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  51
# #######################################
# Diff analysis  DescribeResult(nobs=51, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.059919870712321931, variance=0.021016363861161305, skewness=-0.06876603163064492, kurtosis=-0.18535006632522943)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8861.86
# Real price: 8850.3
# Diff: 0.130654116245
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  52
# #######################################
# Diff analysis  DescribeResult(nobs=52, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.056395326559768838, variance=0.02125024369238758, skewness=-0.10020361674693568, kurtosis=-0.24582215887200176)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8856.91
# Real price: 8846.0
# Diff: 0.12335642522
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  53
# #######################################
# Diff analysis  DescribeResult(nobs=53, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.054629857832801991, variance=0.021006779790614254, skewness=-0.1316419374622719, kurtosis=-0.22786074227036446)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8848.29
# Real price: 8845.0
# Diff: 0.0371745159695
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  54
# #######################################
# Diff analysis  DescribeResult(nobs=54, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.052785712010535536, variance=0.020794072640886559, skewness=-0.16357754159916146, kurtosis=-0.21340637348978087)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8845.47
# Real price: 8841.5
# Diff: 0.0449540165696
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  55
# #######################################
# Diff analysis  DescribeResult(nobs=55, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.05224753122481543, variance=0.02042492734230739, skewness=-0.17612739667964855, kurtosis=-0.16360279680409784)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8842.95
# Real price: 8845.0
# Diff: -0.0231857687959
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  56
# #######################################
# Diff analysis  DescribeResult(nobs=56, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.05258686768448801, variance=0.02006001338403305, skewness=-0.17042726668815408, kurtosis=-0.11556547626045699)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8841.68
# Real price: 8847.98
# Diff: -0.0712503729665
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  57
# #######################################
# Diff analysis  DescribeResult(nobs=57, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.052439580452302618, variance=0.019703035390457764, skewness=-0.1750980397063101, kurtosis=-0.0636912546902022)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8842.09
# Real price: 8846.0
# Diff: -0.0441914954499
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  58
# #######################################
# Diff analysis  DescribeResult(nobs=58, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.054642526475970447, variance=0.019638840431531121, skewness=-0.138681475775725, kurtosis=-0.09517791394381092)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8843.04
# Real price: 8859.0
# Diff: -0.180210449825
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  59
# #######################################
# Diff analysis  DescribeResult(nobs=59, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.058372973273758441, variance=0.020121297499792235, skewness=-0.11676570407426808, kurtosis=-0.19628054868562161)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8845.97
# Real price: 8870.34
# Diff: -0.274738887545
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  60
# #######################################
# Diff analysis  DescribeResult(nobs=60, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.061659846960666703, variance=0.020428470877139181, skewness=-0.08750659397449705, kurtosis=-0.27570216660128066)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8848.57
# Real price: 8871.24
# Diff: -0.255585394488
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  61
# #######################################
# Diff analysis  DescribeResult(nobs=61, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.064009398637641379, variance=0.020424740340569441, skewness=-0.05327449446005741, kurtosis=-0.3089155568091613)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8854.29
# Real price: 8872.48
# Diff: -0.204982499256
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  62
# #######################################
# Diff analysis  DescribeResult(nobs=62, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.063812651684626534, variance=0.020092308512245922, skewness=-0.05788726974704964, kurtosis=-0.2651396249957898)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8867.4
# Real price: 8872.0
# Diff: -0.0518110875507
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  63
# #######################################
# Diff analysis  DescribeResult(nobs=63, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.0624073333358117, variance=0.019892658958788414, skewness=-0.08391686647398917, kurtosis=-0.2503719754147342)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8870.19
# Real price: 8868.0
# Diff: 0.0247224042907
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  64
# #######################################
# Diff analysis  DescribeResult(nobs=64, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.060179020558799208, variance=0.019894686648639696, skewness=-0.11379869274156681, kurtosis=-0.2726713858981573)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8868.13
# Real price: 8861.02
# Diff: 0.080204684393
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  65
# #######################################
# Diff analysis  DescribeResult(nobs=65, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.058049756449559307, variance=0.019878526936803011, skewness=-0.14291098750326586, kurtosis=-0.28953015186726994)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8866.45
# Real price: 8859.52
# Diff: 0.0782231465418
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  66
# #######################################
# Diff analysis  DescribeResult(nobs=66, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.055884848124185919, variance=0.01988203409724747, skewness=-0.1709448315523991, kurtosis=-0.3071885326169874)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8859.52
# Real price: 8852.01
# Diff: 0.0848341930251
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  67
# #######################################
# Diff analysis  DescribeResult(nobs=67, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.054583650138080905, variance=0.019694229941716011, skewness=-0.19511592776009387, kurtosis=-0.2887306664352489)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8854.78
# Real price: 8852.01
# Diff: 0.0312954169448
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  68
# #######################################
# Diff analysis  DescribeResult(nobs=68, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.05486817333342589, variance=0.019405791045753507, skewness=-0.19035034909448403, kurtosis=-0.25141136230449046)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8851.45
# Real price: 8858.0
# Diff: -0.0739312274215
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  69
# #######################################
# Diff analysis  DescribeResult(nobs=69, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.054212237221161183, variance=0.01915009916632163, skewness=-0.20510513357720445, kurtosis=-0.21568033550807986)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8852.32
# Real price: 8853.17
# Diff: -0.00960858158716
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  70
# #######################################
# Diff analysis  DescribeResult(nobs=70, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.054433819101908337, variance=0.018875998394335788, skewness=-0.2016773159137375, kurtosis=-0.17768029764653326)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8852.82
# Real price: 8859.0
# Diff: -0.0697229688735
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  71
# #######################################
# Diff analysis  DescribeResult(nobs=71, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.054144418352330588, variance=0.018612287722780493, skewness=-0.209375445686217, kurtosis=-0.1374210251563186)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8853.0
# Real price: 8856.0
# Diff: -0.0338863658819
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  72
# #######################################
# Diff analysis  DescribeResult(nobs=72, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.053805563284153243, variance=0.018358410063797067, skewness=-0.2181749209525947, kurtosis=-0.09754210186713941)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8853.48
# Real price: 8856.11
# Diff: -0.0297468534436
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  73
# #######################################
# Diff analysis  DescribeResult(nobs=73, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.052422331195819731, variance=0.018243105309988603, skewness=-0.24226021826340982, kurtosis=-0.08836520341664356)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8856.15
# Real price: 8851.97
# Diff: 0.0471703791642
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  74
# #######################################
# Diff analysis  DescribeResult(nobs=74, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.051353239156025215, variance=0.018077778634223822, skewness=-0.26341194828442116, kurtosis=-0.06631811915786257)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8851.05
# Real price: 8848.69
# Diff: 0.026690479749
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  75
# #######################################
# Diff analysis  DescribeResult(nobs=75, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.049648907835051159, variance=0.018051340222229924, skewness=-0.28699815678436075, kurtosis=-0.07310565609877084)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8851.75
# Real price: 8844.99
# Diff: 0.076471609917
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  76
# #######################################
# Diff analysis  DescribeResult(nobs=76, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.048218324080780285, variance=0.017966194996660287, skewness=-0.3102311802195503, kurtosis=-0.06672318621896567)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8844.22
# Real price: 8839.0
# Diff: 0.0590754574895
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  77
# #######################################
# Diff analysis  DescribeResult(nobs=77, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.04710777251261055, variance=0.0178247637025611, skewness=-0.33141201195871034, kurtosis=-0.046787738586128835)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8843.18
# Real price: 8839.88
# Diff: 0.0372941466683
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  78
# #######################################
# Diff analysis  DescribeResult(nobs=78, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.045872157371141753, variance=0.017712359357536005, skewness=-0.3532685802956322, kurtosis=-0.032227371811298866)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8840.35
# Real price: 8836.0
# Diff: 0.049270208522
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  79
# #######################################
# Diff analysis  DescribeResult(nobs=79, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.044980081005320666, variance=0.017548146046465256, skewness=-0.37200634786468234, kurtosis=-0.004828559594119319)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8832.48
# Real price: 8830.31
# Diff: 0.0246018755287
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  80
# #######################################
# Diff analysis  DescribeResult(nobs=80, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.044893585460532806, variance=0.017326616133838794, skewness=-0.37631592921542395, kurtosis=0.03386829708390149)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8836.61
# Real price: 8839.97
# Diff: -0.0380604374223
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  81
# #######################################
# Diff analysis  DescribeResult(nobs=81, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.045520833718623491, variance=0.017141902102725311, skewness=-0.36387801742735704, kurtosis=0.05351169835423919)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8830.54
# Real price: 8839.0
# Diff: -0.0957006943659
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  82
# #######################################
# Diff analysis  DescribeResult(nobs=82, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.046220758471585868, variance=0.016970445043808381, skewness=-0.349662452880886, kurtosis=0.06932662816403523)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8830.9
# Real price: 8840.0
# Diff: -0.102914663462
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  83
# #######################################
# Diff analysis  DescribeResult(nobs=83, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.047882369160138674, variance=0.016992647253598645, skewness=-0.32075060500068797, kurtosis=0.02155343631412121)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8833.7
# Real price: 8850.0
# Diff: -0.184134445621
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  84
# #######################################
# Diff analysis  DescribeResult(nobs=84, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.049896248490672382, variance=0.017128596200264128, skewness=-0.29282877467998464, kurtosis=-0.04800978164535552)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8839.76
# Real price: 8858.99
# Diff: -0.217048232925
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  85
# #######################################
# Diff analysis  DescribeResult(nobs=85, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.051031022268045963, variance=0.017034139820431421, skewness=-0.27032666105123637, kurtosis=-0.05745493890488351)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8841.04
# Real price: 8854.0
# Diff: -0.146352019567
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  86
# #######################################
# Diff analysis  DescribeResult(nobs=86, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.051671784151282797, variance=0.016869047693511961, skewness=-0.2570753789097532, kurtosis=-0.04015192103349685)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8847.3
# Real price: 8856.7
# Diff: -0.106136544226
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  87
# #######################################
# Diff analysis  DescribeResult(nobs=87, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.051652150572425497, variance=0.016672929512680974, skewness=-0.2590236781032909, kurtosis=-0.005588814352385008)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8853.57
# Real price: 8858.0
# Diff: -0.0499636627907
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  88
# #######################################
# Diff analysis  DescribeResult(nobs=88, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.051670228343334991, variance=0.016481315403629616, skewness=-0.2600825408407587, kurtosis=0.028671681097294233)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8854.28
# Real price: 8859.0
# Diff: -0.0532429944125
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  89
# #######################################
# Diff analysis  DescribeResult(nobs=89, minmax=(-0.40147734708612859, 0.21848893981919401), mean=-0.051824597445155628, variance=0.016296148582532494, skewness=-0.2578709748419352, kurtosis=0.06102944276047095)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8855.2
# Real price: 8861.0
# Diff: -0.0654090784054
# 1
# #######################################
# In Cooldown  False
# ...
# ####################################
# #######---> Signals (Phase 3) <---#######
# Buy: -0.215878930839
# ####################################
# Sell: 0.323540721705
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1252
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75713056531927359, 0.41737356576433249), mean=-0.063521298991022379, variance=0.02778625496568474, skewness=-0.6892728551264066, kurtosis=1.9453558931019987)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8513.72
# Real price: 8525.02
# Diff: -0.132531305645
# #######################################
# ########---> Averages (Phase 2) <---############
# #######################################
# Average low: 0.0836410768434
# Average top: -0.225362884524
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75713056531927359, -0.088293940682626262), mean=-0.22536288452434453, variance=0.017719379089269131, skewness=-1.5318425393871686, kurtosis=2.7807970789239747)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(0.00045179048042704622, 0.41737356576433249), mean=0.083641076843430848, variance=0.0076905231615077892, skewness=1.8827326861377522, kurtosis=3.906984732014233)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# #######---> Signals (Phase 3) <---#######
# Buy: -0.215878930839
# ####################################
# Sell: 0.323540721705
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1253
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75713056531927359, 0.41737356576433249), mean=-0.063663831841580962, variance=0.027773404323047257, skewness=-0.6873720403527108, kurtosis=1.9474976495017051)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8513.19
# Real price: 8516.0
# Diff: -0.032991666422
# #######################################
# ########---> Averages (Phase 2) <---############
# #######################################
# Average low: 0.0836410768434
# Average top: -0.225362884524
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75713056531927359, -0.088293940682626262), mean=-0.22536288452434453, variance=0.017719379089269131, skewness=-1.5318425393871686, kurtosis=2.7807970789239747)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(0.00045179048042704622, 0.41737356576433249), mean=0.083641076843430848, variance=0.0076905231615077892, skewness=1.8827326861377522, kurtosis=3.906984732014233)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# #######---> Signals (Phase 3) <---#######
# Buy: -0.215878930839
# ####################################
# Sell: 0.323540721705
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1254
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75713056531927359, 0.41737356576433249), mean=-0.064241630783248613, variance=0.027775160958573235, skewness=-0.6773009096963338, kurtosis=1.9374013345773067)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8513.47
# Real price: 8523.98
# Diff: -0.123245134608
# #######################################
# ########---> Averages (Phase 2) <---############
# #######################################
# Average low: 0.0836410768434
# Average top: -0.225828900443
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75713056531927359, -0.088579086833719289), mean=-0.22582890044335591, variance=0.017606187895610179, skewness=-1.5448269268122272, kurtosis=2.8226510039929336)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(0.00045179048042704622, 0.41737356576433249), mean=0.083641076843430848, variance=0.0076905231615077892, skewness=1.8827326861377522, kurtosis=3.906984732014233)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# #######---> Signals (Phase 3) <---#######
# Buy: -0.215878930839
# ####################################
# Sell: 0.323540721705
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1255
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75713056531927359, 0.41737356576433249), mean=-0.062343582443854982, variance=0.028404139546823172, skewness=-0.6414596688301217, kurtosis=1.849470062971787)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8514.91
# Real price: 8490.17
# Diff: 0.291374650036
# #######################################
# ########---> Averages (Phase 2) <---############
# #######################################
# Average low: 0.0875200483042
# Average top: -0.225828900443
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75713056531927359, -0.088579086833719289), mean=-0.22582890044335591, variance=0.017606187895610179, skewness=-1.5448269268122272, kurtosis=2.8226510039929336)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(0.00073598681111634477, 0.41737356576433249), mean=0.087520048304177853, variance=0.0081649055749734405, skewness=1.7672441419967493, kurtosis=3.1837362602307113)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  True
# #######################################
# Top break:  False
# ####################################
# #######---> Signals (Phase 3) <---#######
# Buy: -0.215878930839
# ####################################
# Sell: 0.329986908804
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1256
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75713056531927359, 0.41737356576433249), mean=-0.062588176585270702, variance=0.028427164287954974, skewness=-0.6366882961112501, kurtosis=1.838061929817414)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8497.07
# Real price: 8508.45
# Diff: -0.133757195053
# #######################################
# ########---> Averages (Phase 2) <---############
# #######################################
# Average low: 0.0875200483042
# Average top: -0.22643127522
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75713056531927359, -0.090397860492379842), mean=-0.22643127521961512, variance=0.017465815915133805, skewness=-1.5603597684120278, kurtosis=2.8751481819535734)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(0.00073598681111634477, 0.41737356576433249), mean=0.087520048304177853, variance=0.0081649055749734405, skewness=1.7672441419967493, kurtosis=3.1837362602307113)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# #######---> Signals (Phase 3) <---#######
# Buy: -0.215878930839
# ####################################
# Sell: 0.329986908804
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1257
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75713056531927359, 0.41737356576433249), mean=-0.063593655774897381, variance=0.028381394899326305, skewness=-0.6227325241953834, kurtosis=1.8373760348971082)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8488.02
# Real price: 8500.0
# Diff: -0.140992647059
# #######################################
# ########---> Averages (Phase 2) <---############
# #######################################
# Average low: 0.086724696299
# Average top: -0.227105872374
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75713056531927359, -0.090411194936212164), mean=-0.22710587237383431, variance=0.017313931295682587, skewness=-1.5767607111159847, kurtosis=2.932755074913823)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(0.00045179048042704622, 0.41737356576433249), mean=0.086724696299030082, variance=0.0082565508937274788, skewness=1.7527433282828215, kurtosis=3.1199702947973194)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# #######---> Signals (Phase 3) <---#######
# Buy: -0.215878930839
# ####################################
# Sell: 0.329986908804
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1258
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75713056531927359, 0.41737356576433249), mean=-0.064890350871087674, variance=0.028174541835510013, skewness=-0.6161490782990181, kurtosis=1.8772661848192893)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8492.07
# Real price: 8501.81
# Diff: -0.114548677723
# #######################################
# ########---> Averages (Phase 2) <---############
# #######################################
# Average low: 0.0847696733073
# Average top: -0.227427705478
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75713056531927359, -0.091853637192610887), mean=-0.2274277054776547, variance=0.017232524795506184, skewness=-1.5873273017607197, kurtosis=2.964532361885862)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0018363828651078284, 0.41737356576433249), mean=0.084769673307291002, variance=0.0083131020690107912, skewness=1.7836776964099266, kurtosis=3.198145899585305)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# #######---> Signals (Phase 3) <---#######
# Buy: -0.215878930839
# ####################################
# Sell: 0.329986908804
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1259
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75713056531927359, 0.41737356576433249), mean=-0.065030934172462515, variance=0.02815062319586293, skewness=-0.6150639742011512, kurtosis=1.883041393484091)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8498.46
# Real price: 8497.98
# Diff: 0.00562495807828
# #######################################
# ########---> Averages (Phase 2) <---############
# #######################################
# Average low: 0.0843947845036
# Average top: -0.227427705478
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75713056531927359, -0.091853637192610887), mean=-0.2274277054776547, variance=0.017232524795506184, skewness=-1.5873273017607197, kurtosis=2.964532361885862)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0018363828651078284, 0.41737356576433249), mean=0.084394784503624795, variance=0.0083624194059723437, skewness=1.773847850879446, kurtosis=3.160792693974477)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# #######---> Signals (Phase 3) <---#######
# Buy: -0.215878930839
# ####################################
# Sell: 0.329986908804
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1260
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.75713056531927359, 0.41737356576433249), mean=-0.065929352812821307, variance=0.028063711530548277, skewness=-0.6046611267180869, kurtosis=1.8978828532723657)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8498.88
# Real price: 8508.0
# Diff: -0.107194607281
# #######################################
# ########---> Averages (Phase 2) <---############
# #######################################
# Average low: 0.0834017488498
# Average top: -0.227632251746
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.75713056531927359, -0.096726299817775696), mean=-0.22763225174550494, variance=0.017179450903240502, skewness=-1.5945298676858923, kurtosis=2.985427331980251)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0019885532475131655, 0.41737356576433249), mean=0.083401748849786225, variance=0.0084603434225512582, skewness=1.7645084497925654, kurtosis=3.105657312764455)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# #######---> Signals (Phase 3) <---#######
# Buy: -0.215878930839
# ####################################
# Sell: 0.329986908804
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-402aa34e4214> in <module>()
#     181                 print "####################################"
#     182
# --> 183     time.sleep(60)
#
# KeyboardInterrupt:
