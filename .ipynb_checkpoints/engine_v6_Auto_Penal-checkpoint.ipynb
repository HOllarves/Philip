# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential, load_model
from scipy import stats
from keras.layers import Dense
from keras.layers import LSTM
import numpy as np
from pytz import timezone
from collections import deque
import MySQLdb
import time
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.offline as py
import Queue
est = timezone('US/Eastern')
# Out:
# Using TensorFlow backend.

# %%
btc = pd.read_csv('binance-data.csv')
twitter_sent = pd.read_csv('live_tweet.csv')
reddit_sent = pd.read_csv('live_reddit.csv')

btc.columns = ["Price","Volume", "Number_Trades", "Market_Cap","Supply", "Stamp"]
twitter_sent.columns = ["Sentiment", "Stamp"]
reddit_sent.columns = ["Sentiment", "Stamp"]

merged = pd.merge(twitter_sent, btc,  on='Stamp', how='inner').merge(reddit_sent, on='Stamp', how='inner')
data = merged[["Sentiment_x", "Sentiment_y","Volume", "Market_Cap", "Supply", "Number_Trades", "Price"]].groupby(merged['Stamp']).mean()
datag = data[["Volume", "Market_Cap", "Supply", "Number_Trades", "Price"]]
tw_sentiment = data["Sentiment_x"]
rdt_sentiment = data["Sentiment_y"]

print "Dataset size: " + str(len(datag))
print "Timespan: " + str(len(datag)/60) + " hours"

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
values = datag.values.reshape(-1, datag.shape[1])
tw_sentiment = tw_sentiment.values.reshape(-1, 1)
rdt_sentiment = rdt_sentiment.values.reshape(-1, 1)
tw_sentiment = tw_sentiment.astype('float32')
rdt_sentiment = rdt_sentiment.astype('float32')
values = values.astype('float32')
scaled = scaler.fit_transform(values)
# Out:
# Dataset size: 12255
# Timespan: 204 hours

# %%
train_size = int(len(scaled) * 0.7)
test_size = len(scaled) - train_size
train, test = scaled[0:train_size,:], scaled[train_size:len(scaled),:]
split = train_size

def create_dataset(dataset, look_back, tw_sentiment, rdt_sentiment, sent=False):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        if i >= look_back:
            a = dataset[i-look_back:i+1, 0]
            a = a.tolist()
            if(sent==True):                
                current_tw_sentiment = tw_sentiment[i].tolist()[0]
                current_rdt_sentiment = rdt_sentiment[i].tolist()[0]
                a.append(current_tw_sentiment)
                a.append(current_rdt_sentiment)
            dataX.append(a)
            dataY.append(dataset[i + look_back, 0])
    print(len(dataY))
    return np.array(dataX), np.array(dataY)

look_back = 5
trainX, trainY = create_dataset(train, look_back, tw_sentiment[0:train_size], rdt_sentiment[0:train_size], sent=True)
testX, testY = create_dataset(test, look_back, tw_sentiment[train_size:len(scaled)], rdt_sentiment[train_size:len(scaled)], sent=True)

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# Creating new model
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(100))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
model.save('models/LSTM_Philip_V6_{0}'.format(datetime.now()) + '.h5')

# Loading model
# model = load_model('models/LSTM_12-03-2018_GOOD.h5')

history = model.fit(trainX, trainY, epochs=300, batch_size=100, validation_data=(testX, testY), verbose=0, shuffle=False)
yhat = model.predict(testX)
yhat_inverse = scaler.inverse_transform(yhat)
testY_inverse = scaler.inverse_transform(testY)
rmse_sent = sqrt(mean_squared_error(testY_inverse, yhat_inverse))

print "Test RMSE: %.3f" % rmse_sent
print "Done"

pyplot.title("Loss")
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

pyplot.title("Prediction")
pyplot.plot(yhat_inverse, label='predict')
pyplot.plot(testY_inverse, label='actual', alpha=0.5)
pyplot.legend()
pyplot.show()
# Out:
# 8568
# 3667
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-8fcaafdeeb68> in <module>()
#      40 history = model.fit(trainX, trainY, epochs=300, batch_size=100, validation_data=(testX, testY), verbose=0, shuffle=False)
#      41 yhat = model.predict(testX)
# ---> 42 yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))
#      43 testY_inverse = scaler.inverse_transform(testY.reshape(-1, 1))
#      44 rmse_sent = sqrt(mean_squared_error(testY_inverse, yhat_inverse))
#
# /home/thriven/anaconda3/envs/py27/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in inverse_transform(self, X)
#     383         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES)
#     384
# --> 385         X -= self.min_
#     386         X /= self.scale_
#     387         return X
#
# ValueError: non-broadcastable output operand with shape (3667,1) doesn't match the broadcast shape (3667,5)

# %%
#Enter the values for you database connection
dsn_database = "ai_datasets_v6" # e.g. "MySQLdbtest"
dsn_hostname = "127.0.0.1"      # e.g.: "mydbinstance.xyz.us-east-1.rds.amazonaws.com"
dsn_port = 3306                 # e.g. 3306 
dsn_uid = "root"                # e.g. "user1"
dsn_pwd = ""                    # e.g. "Password123"

# %%
true_q = Queue.Queue()
pred_q = Queue.Queue()

def process_data(in_data):
    out_data = []
    for line in in_data:
        out_data.append(float(line.split(',')[0]))
    return np.array(out_data).reshape(-1,1)

def get_last_trade():
    conn = MySQLdb.connect(host=dsn_hostname, port=dsn_port, user=dsn_uid, passwd=dsn_pwd, db=dsn_database)
    cursor = conn.cursor()
    cursor.execute ("select * from trades order by date desc limit 1")
    return cursor.fetchone()

# %%
diffs = deque([], maxlen=200)
lows = []
tops = []
last_trade = ()
top_lows = deque([], maxlen=30)
top_tops = deque([], maxlen=30)
bought = False
to_db = False
prev = 8502
in_cooldown = False
minute_ = 0
status = 0
current_decision = 0
penalized = False
penalization_count = 0
penalized_zero = 0
penalized_bottom = 0
penalized_top = 0
reversal_top = 0
reversal_down = 0

while True:
    
    # Processing data
    minute_ = minute_ + 1
    btc = open('binance-data.csv','r')
    tw_sent = open('live_tweet.csv','r')
    rdt_sent = open('live_reddit.csv','r')
    bit_data = btc.readlines()
    tw_sent_data = tw_sent.readlines()
    rdt_sent_data = rdt_sent.readlines()
    bit_data = process_data(bit_data[len(bit_data)-5:])
    tw_sent_data = process_data(tw_sent_data[len(tw_sent_data)-5:])
    rdt_sent_data = process_data(rdt_sent_data[len(rdt_sent_data)-5:])
    
    # Last price recieved
    real_price = bit_data[len(bit_data) - 1][0]
    
    # Scaling prices
    live = scaler.fit_transform(bit_data)
    
    # Creating datasets and making prediction
    testX, testY = create_dataset(live, 2, tw_sent_data, rdt_sent_data, sent=True)
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
    yhat = model.predict(testX)
    
    #Re scaling prices
    yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))
    
    # Save real price and prediction price
    true_q.put(bit_data[4])
    pred_q.put(yhat_inverse[0])
    
    # Diference between real price and prediction
    alpha_diff = 100 * ((yhat_inverse[0][0] - float(real_price))/float(real_price))
    diffs.append(alpha_diff)
    diff_analisis = stats.describe(diffs)
    
    print "#######################################"
    print "In Cooldown ", in_cooldown
    print "#######################################"
    print "Minute: ", minute_
    print "#######################################"
    print "Diff analysis ", diff_analisis
    print "#######################################"
    print "########---> Initial values <---#######"
    print "#######################################"
    print "Pred: " + str(yhat_inverse[0][0])
    print "Real price: " + str(real_price)
    print "Diff: " + str(alpha_diff)

    if(len(diffs) >= 200):
        
        # Sorting all diffs
        sorted_diffs = sorted(diffs)
        # Taking the highest 15 (most negative)
        tops = sorted_diffs[0:75]
        # Taking the lowest 5 (most positive)
        lows = sorted_diffs[-75:]
        # Analyzing lists
        low_analisis = stats.describe(lows)
        top_analisis = stats.describe(tops)
        
        # Getting averages of tops and lows
        top_threshold = top_analisis.mean
        low_threshold = low_analisis.mean
        
        print "#######################################"
        print "######---> Averages (Phase 2) <---#####"
        print "#######################################"
        print "Average low: " + str(low_threshold)
        print "Average top: " + str(top_threshold)
        print "#######################################"
        print "#######################################"
        print "Top analysis", top_analisis
        print "#######################################"
        print "#######################################"
        print "Low analysis", low_analisis
        print "#######################################"
        print "#######################################"
        print "Low length", len(top_lows)
        print "Top length", len(top_tops)
        print "#######################################"
        print "#######################################"
        print "Low break: ", alpha_diff > low_threshold
        print "#######################################"
        print "Top break: ", alpha_diff < top_threshold 
        
        # If diff is greater than the average low
        if(alpha_diff > low_threshold):
            # Adding to top_lows list
            top_lows.append(alpha_diff)
            # Sorting
            sorted_lows = sorted(top_lows)
            top_lows = deque(sorted_lows, maxlen=30)
            
        # If diff is lower than the average high
        if(alpha_diff < top_threshold):
            # Adding to top_tops list
            top_tops.append(alpha_diff)            
            # Sorting 
            sorted_tops = sorted(top_tops)
            top_tops = deque(sorted_tops, maxlen=30)
             
        if(len(top_tops) >= 30 and len(top_lows) >= 30):
            # Analyzing top_tops and top_lows
            alpha_top_analisis = stats.describe(top_tops)
            alpha_low_analisis = stats.describe(top_lows)

            # Getting averages of top_tops and top_lows analisis
            alpha_top = alpha_top_analisis.mean
            alpha_low = alpha_low_analisis.mean

            print "####################################"
            print "####---> Signals (Phase 3) <---#####"
            print "Buy: " + str(alpha_top - alpha_top_analisis.variance)
            print "####################################"
            print "Sell: " + str(alpha_low)

            if(not in_cooldown):
                
                if bought:
                    status = ((real_price - buy_price) / buy_price) * 100
                    print "####################################"
                    print "Current status"
                    print "####################################"
                    print "Status", status
                    print "####################################"
                    if status >= 0.15 and alpha_low > 0.05:
                        alpha_low = 0.05
                
                # If two bad trades in a row were made, philip is penalized
                if penalization_count >= 2:
                    penalized = True
                        
                if not penalized:
                    # If difference is lower that than the lowest top (negative value) -> BUY
                    if alpha_diff < alpha_top - alpha_top_analisis.variance  and not bought:
                        decision = 1
                        print "Buy at: " + str(real_price)
                        bought = True
                        to_db = True
                        in_cooldown = True
                        buy_price = real_price
                    # If difference is greater than the average low in the top_lows list -> SELL
                    elif alpha_diff > alpha_low and bought:
                        decision = 2
                        print "Sell at: " + str(real_price)
                        bought = False
                        to_db = True
                        in_cooldown = True
                        buy_price = 0
                        # If a trade is not succesful
                        if status <= 0.1:
                            # Add to penalization count
                            penalization_count = penalization_count + 1
                            if penalization_count >= 2:
                                # If penalization threshold is broken,
                                # we set all variables to the penalization price
                                penalized_zero = real_price
                                penalized_top = real_price
                                penalized_bottom = real_price
                        else:
                            # If a good trade was done, penalization count is reset
                            penalization_count = 0
                        status = 0
                    else:
                        to_db = False
                    if to_db == True:  # Saving decision to DB
                        conn = MySQLdb.connect(host=dsn_hostname, port=dsn_port, user=dsn_uid, passwd=dsn_pwd, db=dsn_database)
                        cursor=conn.cursor()
                        input_string = "INSERT INTO live_data (yhat, bit_data, sent_data, reddit_sent, date, decision) values ({},{},{},{},'{}',{});".format(
                            yhat_inverse[0][0],
                            bit_data[0][0],
                            tw_sent_data[4][0],
                            rdt_sent_data[4][0],
                            datetime.now(tz=est).strftime('%Y-%m-%d %H:%M:%S'),
                            decision)
                        cursor.execute(input_string)
                        current_decision = cursor.lastrowid
                        conn.commit()
                        cursor.close()
                        to_db = False
                else: # If Philip is penalized
                    
                    print "####################################"
                    print "Penalization!"

                    
                    # Getting top and bottoms in comparison to the penalization price
                    if real_price > penalized_zero and real_price > penalized_top:
                        penalized_top = real_price
                    if real_price < penalized_zero and real_price < penalized_bottom:
                        penalized_bottom = real_price
                    
                    # Calculating reversals
                    reversal_top = ((penalized_top - penalized_zero) / penalized_top) * 100
                    reversal_down = ((real_price - penalized_bottom) / real_price) * 100
                    
                    # If any of the reversal thresholds are broken, penalization is over
                    if reversal_top >= 2 or reversal_down >= 2:
                        penalized = False
                        
                    print "####################################"
                    print "Penalized Zero: ", penalized_zero
                    print "####################################"
                    print "Penalized Top: ", penalized_top
                    print "####################################"
                    print "Penalized Bottom: ", penalized_bottom
                    print "####################################"
                    print "Reversal Top: ", reversal_top
                    print "####################################"
                    print "Reversal Bottom: ", reversal_down
                                            
            else:
                last_trade = get_last_trade()
                if len(last_trade) is not 0 and current_decision == last_trade[3]:
                    in_cooldown = False
                print "####################################"
                print "In Cooldown"
                print "####################################"
                print "Last trade", last_trade
                print "####################################"
                print "Current decision", current_decision
                print "####################################"
    time.sleep(60)
# Out:
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1
# #######################################
# Diff analysis  DescribeResult(nobs=1, minmax=(-0.0092099688027385447, -0.0092099688027385447), mean=-0.0092099688027385447, variance=nan, skewness=0.0, kurtosis=-3.0)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8519.2
# Real price: 8519.98
# Diff: -0.00920996880274
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  2
# #######################################
# Diff analysis  DescribeResult(nobs=2, minmax=(-0.0092099688027385447, 0.31645479930695675), mean=0.1536224152521091, variance=0.053028770593970806, skewness=0.0, kurtosis=-2.0)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8516.95
# Real price: 8490.08
# Diff: 0.316454799307
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  3
# #######################################
# Diff analysis  DescribeResult(nobs=3, minmax=(-0.19893537674503589, 0.31645479930695675), mean=0.036103151253060767, variance=0.067946717529619463, skewness=0.3097064896821279, kurtosis=-1.5)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8495.06
# Real price: 8511.99
# Diff: -0.198935376745
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  4
# #######################################
# Diff analysis  DescribeResult(nobs=4, minmax=(-0.19893537674503589, 0.31645479930695675), mean=-0.021945982191671973, variance=0.058776619261150527, skewness=0.7543750091943222, kurtosis=-1.0683592629940981)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8487.32
# Real price: 8504.0
# Diff: -0.196093382526
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  5
# #######################################
# Diff analysis  DescribeResult(nobs=5, minmax=(-0.19893537674503589, 0.31645479930695675), mean=-0.0209878049189159, variance=0.044087054964293021, skewness=0.8279821898426751, kurtosis=-0.6030056297859963)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8491.37
# Real price: 8492.83
# Diff: -0.0171550958279
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  6
# #######################################
# Diff analysis  DescribeResult(nobs=6, minmax=(-0.19893537674503589, 0.31645479930695675), mean=0.0090435526865363172, variance=0.040680938609193737, skewness=0.3947490808817462, kurtosis=-1.1029352753657724)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8497.17
# Real price: 8483.66
# Diff: 0.159200340714
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  7
# #######################################
# Diff analysis  DescribeResult(nobs=7, minmax=(-0.19893537674503589, 0.31645479930695675), mean=0.045886258388966886, variance=0.043402476918659484, skewness=0.05582368911309433, kurtosis=-1.4560081596144898)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8472.56
# Real price: 8450.0
# Diff: 0.266942492604
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  8
# #######################################
# Diff analysis  DescribeResult(nobs=8, minmax=(-0.19893537674503589, 0.31645479930695675), mean=0.038978283645588988, variance=0.037583883993577878, skewness=0.1695678611723904, kurtosis=-1.2528962322950021)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8465.25
# Real price: 8466.04
# Diff: -0.00937753955806
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  9
# #######################################
# Diff analysis  DescribeResult(nobs=9, minmax=(-0.19893537674503589, 0.31645479930695675), mean=0.03111414266964041, variance=0.033442500913986983, skewness=0.3046267556382294, kurtosis=-1.053142663181759)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8452.4
# Real price: 8455.09
# Diff: -0.0317989851379
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  10
# #######################################
# Diff analysis  DescribeResult(nobs=10, minmax=(-0.20707270614498066, 0.31645479930695675), mean=0.007295457788178303, variance=0.035399964973923455, skewness=0.41217711935708146, kurtosis=-1.0446809900338083)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8451.5
# Real price: 8469.04
# Diff: -0.207072706145
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  11
# #######################################
# Diff analysis  DescribeResult(nobs=11, minmax=(-0.20707270614498066, 0.31645479930695675), mean=-0.00189450870447741, variance=0.032788978802028593, skewness=0.5556421442090395, kurtosis=-0.8573211592703576)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8452.99
# Real price: 8460.93
# Diff: -0.093794173631
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  12
# #######################################
# Diff analysis  DescribeResult(nobs=12, minmax=(-0.20707270614498066, 0.31645479930695675), mean=-0.00079666749586957851, variance=0.029822625611130537, skewness=0.5600493582310997, kurtosis=-0.6799346611845691)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8450.95
# Real price: 8450.0
# Diff: 0.0112795857988
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  13
# #######################################
# Diff analysis  DescribeResult(nobs=13, minmax=(-0.20707270614498066, 0.31645479930695675), mean=0.022611385961884514, variance=0.034460587377056942, skewness=0.3979403554775234, kurtosis=-1.0789501283100862)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8457.59
# Real price: 8432.0
# Diff: 0.303508027455
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  14
# #######################################
# Diff analysis  DescribeResult(nobs=14, minmax=(-0.20707270614498066, 0.31645479930695675), mean=0.010383577887664443, variance=0.033903043027636637, skewness=0.5182350819576369, kurtosis=-1.002523183034698)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8443.23
# Real price: 8455.79
# Diff: -0.148577927077
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  15
# #######################################
# Diff analysis  DescribeResult(nobs=15, minmax=(-0.20707270614498066, 0.31645479930695675), mean=0.0068078408137815941, variance=0.031673185531414259, skewness=0.5919355937310229, kurtosis=-0.8384079586208415)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8434.36
# Real price: 8438.01
# Diff: -0.0432524782206
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  16
# #######################################
# Diff analysis  DescribeResult(nobs=16, minmax=(-0.20707270614498066, 0.31645479930695675), mean=0.0012674021828698902, variance=0.030052783192886359, skewness=0.6862761285446335, kurtosis=-0.6801150184131264)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8433.09
# Real price: 8440.0
# Diff: -0.0818391772808
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  17
# #######################################
# Diff analysis  DescribeResult(nobs=17, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.012481572227614755, variance=0.031388067298113706, skewness=0.6941512666706079, kurtosis=-0.6291629196314354)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8435.74
# Real price: 8455.4
# Diff: -0.232465162795
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  18
# #######################################
# Diff analysis  DescribeResult(nobs=18, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.020838171541157732, variance=0.030798699935792592, skewness=0.7799951115051751, kurtosis=-0.5183512889745856)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8439.25
# Real price: 8453.02
# Diff: -0.162900359871
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  19
# #######################################
# Diff analysis  DescribeResult(nobs=19, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.026837916444633882, variance=0.029771602889699759, skewness=0.8646741060287784, kurtosis=-0.37238048830040915)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8441.6
# Real price: 8453.0
# Diff: -0.134833324707
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  20
# #######################################
# Diff analysis  DescribeResult(nobs=20, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.029174305902513402, variance=0.028313850735798628, skewness=0.9235944446270666, kurtosis=-0.20363276555895116)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8445.78
# Real price: 8452.0
# Diff: -0.0735657056022
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  21
# #######################################
# Diff analysis  DescribeResult(nobs=21, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.027481820815862298, variance=0.026958312820147969, skewness=0.9120673110165246, kurtosis=-0.11599292436386799)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8450.54
# Real price: 8450.0
# Diff: 0.00636788091716
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  22
# #######################################
# Diff analysis  DescribeResult(nobs=22, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.02427176480569733, variance=0.025901281749180875, skewness=0.8641656515221461, kurtosis=-0.10253540924598825)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8449.64
# Real price: 8446.0
# Diff: 0.0431394114078
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  23
# #######################################
# Diff analysis  DescribeResult(nobs=23, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.025497430517523116, variance=0.024758502658636085, skewness=0.9053654846974462, kurtosis=0.04923041715674259)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8448.7
# Real price: 8453.13
# Diff: -0.0524620761777
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  24
# #######################################
# Diff analysis  DescribeResult(nobs=24, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.029315988847190878, variance=0.024031999326513887, skewness=0.9710364107372136, kurtosis=0.18928894023499243)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8446.28
# Real price: 8456.19
# Diff: -0.11714283043
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  25
# #######################################
# Diff analysis  DescribeResult(nobs=25, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.029430659811727749, variance=0.02303099475699517, skewness=0.9933519520993822, kurtosis=0.325141831382354)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8447.31
# Real price: 8450.03
# Diff: -0.0321827629606
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  26
# #######################################
# Diff analysis  DescribeResult(nobs=26, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.030336764015054276, variance=0.022131101612224802, skewness=1.0300314744157129, kurtosis=0.4768662238858612)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8449.53
# Real price: 8454.01
# Diff: -0.0529893690982
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  27
# #######################################
# Diff analysis  DescribeResult(nobs=27, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.035624468610720814, variance=0.022034820533427892, skewness=1.070253959605493, kurtosis=0.5491006961919775)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8450.35
# Real price: 8465.0
# Diff: -0.173104788098
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  28
# #######################################
# Diff analysis  DescribeResult(nobs=28, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.04052931241301639, variance=0.021892325865524545, skewness=1.1111309175185038, kurtosis=0.6292462208693705)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8452.36
# Real price: 8467.0
# Diff: -0.172960095075
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  29
# #######################################
# Diff analysis  DescribeResult(nobs=29, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.043953429408008893, variance=0.021450469823279448, skewness=1.1640835745764782, kurtosis=0.7558502914319449)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8453.54
# Real price: 8465.38
# Diff: -0.139828705268
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  30
# #######################################
# Diff analysis  DescribeResult(nobs=30, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.046051053737929296, variance=0.020842799284947141, skewness=1.214186413835256, kurtosis=0.9080545409032421)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8458.95
# Real price: 8468.0
# Diff: -0.106882159306
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  31
# #######################################
# Diff analysis  DescribeResult(nobs=31, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.044833076031295133, variance=0.020194026869291826, skewness=1.204540334574814, kurtosis=0.9776885983991477)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8465.3
# Real price: 8466.0
# Diff: -0.00829374483227
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  32
# #######################################
# Diff analysis  DescribeResult(nobs=32, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.045531410981368023, variance=0.019558212142181553, skewness=1.2374361879506364, kurtosis=1.1244303697593194)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8466.27
# Real price: 8471.96
# Diff: -0.0671797944336
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  33
# #######################################
# Diff analysis  DescribeResult(nobs=33, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.043885898553501786, variance=0.019036372480697037, skewness=1.2133840690367361, kurtosis=1.1545938130345004)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8465.73
# Real price: 8464.99
# Diff: 0.00877049913822
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  34
# #######################################
# Diff analysis  DescribeResult(nobs=34, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.041518171047136537, variance=0.018650121249064251, skewness=1.166298327834298, kurtosis=1.1132541131442277)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8462.11
# Real price: 8459.01
# Diff: 0.0366168366629
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  35
# #######################################
# Diff analysis  DescribeResult(nobs=35, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.033212319707564018, variance=0.020516139097778347, skewness=1.0534684551478646, kurtosis=0.5412444839332853)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8464.84
# Real price: 8443.8
# Diff: 0.249186625838
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  36
# #######################################
# Diff analysis  DescribeResult(nobs=36, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.029833572453341579, variance=0.020340937283269644, skewness=0.9820784862445621, kurtosis=0.41442535184263507)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8452.49
# Real price: 8445.02
# Diff: 0.0884225814444
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  37
# #######################################
# Diff analysis  DescribeResult(nobs=37, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.026178041487287095, variance=0.020270338793443244, skewness=0.9054579872365318, kurtosis=0.2650765860611175)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8447.9
# Real price: 8439.0
# Diff: 0.105421073291
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  38
# #######################################
# Diff analysis  DescribeResult(nobs=38, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.025126769279388308, variance=0.019764488382719665, skewness=0.8925827383681866, kurtosis=0.3118663072196446)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8440.12
# Real price: 8438.96
# Diff: 0.0137703024129
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  39
# #######################################
# Diff analysis  DescribeResult(nobs=39, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.02513038955344455, variance=0.019244370778533929, skewness=0.904330260036168, kurtosis=0.3991161340324383)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8438.03
# Real price: 8440.16
# Diff: -0.0252679599676
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  40
# #######################################
# Diff analysis  DescribeResult(nobs=40, minmax=(-0.23246516279536908, 0.31645479930695675), mean=-0.027557744361807347, variance=0.018986607428583414, skewness=0.9432929618307596, kurtosis=0.4721484487268044)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8438.96
# Real price: 8449.29
# Diff: -0.122224581888
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  41
# #######################################
# Diff analysis  DescribeResult(nobs=41, minmax=(-0.36468214568631929, 0.31645479930695675), mean=-0.035780290735575926, variance=0.021283963266488602, skewness=0.6337081530418702, kurtosis=0.548047159713942)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8439.5
# Real price: 8470.39
# Diff: -0.364682145686
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  42
# #######################################
# Diff analysis  DescribeResult(nobs=42, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.045562235093260794, variance=0.024783672498715784, skewness=0.24204743007383944, kurtosis=0.7474615851378759)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8440.21
# Real price: 8478.07
# Diff: -0.446621953758
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  43
# #######################################
# Diff analysis  DescribeResult(nobs=43, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.048088965630175368, variance=0.02446811284813577, skewness=0.28176613750678176, kurtosis=0.7735680970360144)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8447.37
# Real price: 8460.42
# Diff: -0.154211648181
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  44
# #######################################
# Diff analysis  DescribeResult(nobs=44, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.047421312091792928, variance=0.023918700462828398, skewness=0.27173355095896856, kurtosis=0.8501654772828973)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8459.64
# Real price: 8461.22
# Diff: -0.0187122099413
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  45
# #######################################
# Diff analysis  DescribeResult(nobs=45, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.052333311261993844, variance=0.024460841747290209, skewness=0.28714560140062007, kurtosis=0.7190259908007652)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8458.26
# Real price: 8481.03
# Diff: -0.268461274751
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  46
# #######################################
# Diff analysis  DescribeResult(nobs=46, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.056073056945575905, variance=0.024560609584021367, skewness=0.3216636161847869, kurtosis=0.6656469586088254)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8461.96
# Real price: 8480.99
# Diff: -0.224361612707
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  47
# #######################################
# Diff analysis  DescribeResult(nobs=47, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.056261119683074894, variance=0.024028345565598627, skewness=0.32878236976878966, kurtosis=0.7464207576375443)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8464.5
# Real price: 8470.0
# Diff: -0.064912005608
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  48
# #######################################
# Diff analysis  DescribeResult(nobs=48, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.053660543990971109, variance=0.02384172787924322, skewness=0.2857929154277419, kurtosis=0.7107353950197575)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8469.81
# Real price: 8464.01
# Diff: 0.0685665135379
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  49
# #######################################
# Diff analysis  DescribeResult(nobs=49, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.050243068057936956, variance=0.023917303160982829, skewness=0.23818376239100642, kurtosis=0.6139071637504547)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8474.63
# Real price: 8465.0
# Diff: 0.113795776728
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  50
# #######################################
# Diff analysis  DescribeResult(nobs=50, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.049159066487091271, variance=0.023487947903487471, skewness=0.2191766067843759, kurtosis=0.6629902505372081)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8465.33
# Real price: 8465.0
# Diff: 0.00395701048435
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  51
# #######################################
# Diff analysis  DescribeResult(nobs=51, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.047641759004273053, variance=0.023135602267285948, skewness=0.19210911888602045, kurtosis=0.6914391102346973)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8455.39
# Real price: 8453.0
# Diff: 0.0282236151366
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  52
# #######################################
# Diff analysis  DescribeResult(nobs=52, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.046721193744100178, variance=0.022726029907851417, skewness=0.17555489359093496, kurtosis=0.7448831407391148)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8459.99
# Real price: 8459.97
# Diff: 0.000227634524716
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  53
# #######################################
# Diff analysis  DescribeResult(nobs=53, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.047354625682994457, variance=0.022310256380286164, skewness=0.1896053170889615, kurtosis=0.812814399673699)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8452.21
# Real price: 8459.0
# Diff: -0.0802930865055
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  54
# #######################################
# Diff analysis  DescribeResult(nobs=54, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.046335065679573746, variance=0.021945441287126929, skewness=0.1707880656362178, kurtosis=0.8602377792813876)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8451.09
# Real price: 8450.44
# Diff: 0.00770161450172
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  55
# #######################################
# Diff analysis  DescribeResult(nobs=55, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.046080912969424147, variance=0.021542596874258409, skewness=0.16709302908494067, kurtosis=0.9292422014408213)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8456.08
# Real price: 8458.82
# Diff: -0.0323566666213
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  56
# #######################################
# Diff analysis  DescribeResult(nobs=56, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.044993773916456876, variance=0.021217098088673687, skewness=0.14656286183352074, kurtosis=0.9715719016354534)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8451.27
# Real price: 8450.02
# Diff: 0.0147988739967
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  57
# #######################################
# Diff analysis  DescribeResult(nobs=57, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.045572065745168325, variance=0.020857283359122025, skewness=0.15956831417742018, kurtosis=1.0376370341878562)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8450.41
# Real price: 8457.0
# Diff: -0.077956408153
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  58
# #######################################
# Diff analysis  DescribeResult(nobs=58, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.046736790298106477, variance=0.020570047937692192, skewness=0.18276612809592768, kurtosis=1.0835672814782198)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8449.43
# Real price: 8459.0
# Diff: -0.113126089816
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  59
# #######################################
# Diff analysis  DescribeResult(nobs=59, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.047463778597619508, variance=0.020246574146036565, skewness=0.19889222726332484, kurtosis=1.1452732994695172)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8450.41
# Real price: 8457.99
# Diff: -0.0896290999694
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  60
# #######################################
# Diff analysis  DescribeResult(nobs=60, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.048786650101092642, variance=0.020008411213256999, skewness=0.22426812448724925, kurtosis=1.181039558474418)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8452.92
# Real price: 8463.65
# Diff: -0.126836068806
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  61
# #######################################
# Diff analysis  DescribeResult(nobs=61, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.049288903739479799, variance=0.019690325474789713, skewness=0.23651639024431678, kurtosis=1.24745705635545)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8457.53
# Real price: 8464.25
# Diff: -0.0794241220427
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  62
# #######################################
# Diff analysis  DescribeResult(nobs=62, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.048663905704350544, variance=0.019391751851614285, skewness=0.2247821755613595, kurtosis=1.302219571855031)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8459.11
# Real price: 8460.0
# Diff: -0.0105390255615
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  63
# #######################################
# Diff analysis  DescribeResult(nobs=63, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.046447215709762568, variance=0.01938854567598192, skewness=0.18943834987172334, kurtosis=1.2360046773007713)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8460.94
# Real price: 8453.25
# Diff: 0.0909875639547
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  64
# #######################################
# Diff analysis  DescribeResult(nobs=64, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.044229765524524192, variance=0.019395484443449233, skewness=0.15508842750489202, kurtosis=1.1706212253007493)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8460.0
# Real price: 8451.93
# Diff: 0.0954695961455
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  65
# #######################################
# Diff analysis  DescribeResult(nobs=65, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.042600480109425368, variance=0.019264977111670835, skewness=0.12570368181947017, kurtosis=1.1588417119666818)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8453.2
# Real price: 8447.99
# Diff: 0.0616737864569
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  66
# #######################################
# Diff analysis  DescribeResult(nobs=66, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.041094100781637069, variance=0.019118358641240767, skewness=0.09800922733602438, kurtosis=1.1560718939925216)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8442.4
# Real price: 8437.61
# Diff: 0.0568205555246
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  67
# #######################################
# Diff analysis  DescribeResult(nobs=67, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.03957910910757783, variance=0.018982464925371312, skewness=0.07041760247173318, kurtosis=1.1516361933213668)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8445.1
# Real price: 8440.0
# Diff: 0.0604103413803
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  68
# #######################################
# Diff analysis  DescribeResult(nobs=68, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.03581735541935778, variance=0.019661398328487775, skewness=0.07598530159138672, kurtosis=0.966432712849894)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8430.84
# Real price: 8412.65
# Diff: 0.216220141691
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  69
# #######################################
# Diff analysis  DescribeResult(nobs=69, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.032358392969819905, variance=0.020197805182459321, skewness=0.06849238590798616, kurtosis=0.8108412770539402)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8408.26
# Real price: 8391.24
# Diff: 0.202851053599
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  70
# #######################################
# Diff analysis  DescribeResult(nobs=70, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.029957234725794153, variance=0.020308672632120474, skewness=0.03997341233927431, kurtosis=0.7379489874167966)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8423.42
# Real price: 8412.0
# Diff: 0.135722684112
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  71
# #######################################
# Diff analysis  DescribeResult(nobs=71, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.028195940970711694, variance=0.020238801791486065, skewness=0.011966461361217253, kurtosis=0.7163980666339858)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8394.98
# Real price: 8387.0
# Diff: 0.0950946218851
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  72
# #######################################
# Diff analysis  DescribeResult(nobs=72, minmax=(-0.44662195375834018, 0.31645479930695675), mean=-0.030370467157546661, variance=0.020294204863007741, skewness=0.039038205927354054, kurtosis=0.6651739069722242)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8388.11
# Real price: 8403.64
# Diff: -0.184761826423
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  73
# #######################################
# Diff analysis  DescribeResult(nobs=73, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.0366912652850101, variance=0.022928872601251687, skewness=-0.23748510497933714, kurtosis=0.99445738965133)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8387.8
# Real price: 8429.25
# Diff: -0.491788730462
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  74
# #######################################
# Diff analysis  DescribeResult(nobs=74, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.042306283489987155, variance=0.024947882234753617, skewness=-0.3500291767418513, kurtosis=0.9344809407915955)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8391.6
# Real price: 8429.72
# Diff: -0.452202612453
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  75
# #######################################
# Diff analysis  DescribeResult(nobs=75, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.045007526740213605, variance=0.025158002323307772, skewness=-0.31786005152671676, kurtosis=0.8289436585135492)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8398.33
# Real price: 8418.95
# Diff: -0.244899527257
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  76
# #######################################
# Diff analysis  DescribeResult(nobs=76, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.046772572291097887, variance=0.025059331612879265, skewness=-0.28994175361920954, kurtosis=0.8002171420624506)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8414.94
# Real price: 8430.04
# Diff: -0.179150988607
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  77
# #######################################
# Diff analysis  DescribeResult(nobs=77, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.04717148693324557, variance=0.024741856798003805, skewness=-0.28406672090549123, kurtosis=0.8434870756743127)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8417.7
# Real price: 8424.23
# Diff: -0.0774889997365
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  78
# #######################################
# Diff analysis  DescribeResult(nobs=78, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.04695220395375458, variance=0.024424284614402682, skewness=-0.290058971512398, kurtosis=0.8938352355748806)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8419.43
# Real price: 8421.96
# Diff: -0.0300674145329
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  79
# #######################################
# Diff analysis  DescribeResult(nobs=79, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.047098730892764701, variance=0.024112848901736476, skewness=-0.2890380233434923, kurtosis=0.942098458403235)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8421.75
# Real price: 8426.68
# Diff: -0.0585278321356
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  80
# #######################################
# Diff analysis  DescribeResult(nobs=80, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.046873527218400393, variance=0.023811680301867231, skewness=-0.2951729025499198, kurtosis=0.9923615780924311)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8422.55
# Real price: 8425.0
# Diff: -0.0290824369436
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  81
# #######################################
# Diff analysis  DescribeResult(nobs=81, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.045917320341654966, variance=0.023588095156975849, skewness=-0.3127955805553815, kurtosis=1.0253439272915026)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8417.57
# Real price: 8415.0
# Diff: 0.030579229798
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  82
# #######################################
# Diff analysis  DescribeResult(nobs=82, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.043531530725803576, variance=0.023763627457125711, skewness=-0.3268241639058271, kurtosis=0.9678564735603468)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8422.73
# Real price: 8410.14
# Diff: 0.149717428158
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  83
# #######################################
# Diff analysis  DescribeResult(nobs=83, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.043950661226077006, variance=0.023488407763512253, skewness=-0.3203940864058432, kurtosis=1.0077214846882052)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8418.39
# Real price: 8424.99
# Diff: -0.0783193622485
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  84
# #######################################
# Diff analysis  DescribeResult(nobs=84, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.043673137070723636, variance=0.023211884550063209, skewness=-0.3276377596075027, kurtosis=1.0561347401600605)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8411.26
# Real price: 8413.0
# Diff: -0.0206386321764
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  85
# #######################################
# Diff analysis  DescribeResult(nobs=85, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.043251924570914521, variance=0.022950633288583499, skewness=-0.3374900050654627, kurtosis=1.1027961773526433)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8412.34
# Real price: 8413.0
# Diff: -0.00787007458695
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  86
# #######################################
# Diff analysis  DescribeResult(nobs=86, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.041717216261535357, variance=0.022883184183289031, skewness=-0.35772775929463324, kurtosis=1.098775925528714)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8412.46
# Real price: 8405.0
# Diff: 0.0887329900357
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  87
# #######################################
# Diff analysis  DescribeResult(nobs=87, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.040218857000930759, variance=0.022812422647498089, skewness=-0.3776062771909481, kurtosis=1.096736429804551)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8412.45
# Real price: 8405.0
# Diff: 0.0886400394111
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  88
# #######################################
# Diff analysis  DescribeResult(nobs=88, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.039545398112325464, variance=0.022590123017897593, skewness=-0.391574911066419, kurtosis=1.1364133410192583)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8405.6
# Real price: 8404.0
# Diff: 0.0190455251963
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  89
# #######################################
# Diff analysis  DescribeResult(nobs=89, minmax=(-0.49178873046237803, 0.31645479930695675), mean=-0.038221736594969531, variance=0.022489352177827472, skewness=-0.41079516994542137, kurtosis=1.1440953403696144)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8408.61
# Real price: 8402.03
# Diff: 0.0782604769324
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  90
# #######################################
# ...
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.17460372279
# ####################################
# Sell: 0.286251435816
# ####################################
# Current status
# ####################################
# Status -0.708866924035
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1429
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.23352413283501261, 0.22510937647281232), mean=-0.017771231410843306, variance=0.0041501200000677169, skewness=-0.39881320500702244, kurtosis=2.901779319253607)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8399.67
# Real price: 8400.01
# Diff: -0.00407179574786
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0261825499774
# Average top: -0.0708579699077
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.23352413283501261, -0.0040717957478648035), mean=-0.070857969907698118, variance=0.0038527981004826449, skewness=-0.7589393528077406, kurtosis=-0.3633070224781334)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0040717957478648035, 0.22510937647281232), mean=0.026182549977359179, variance=0.0023665248785392531, skewness=2.270494467850492, kurtosis=5.144166386006088)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.17460372279
# ####################################
# Sell: 0.286251435816
# ####################################
# Current status
# ####################################
# Status -0.708866924035
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1430
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.23352413283501261, 0.22510937647281232), mean=-0.017509409297673827, variance=0.0041434817244709026, skewness=-0.41086471863704954, kurtosis=2.926659585498137)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8399.67
# Real price: 8400.01
# Diff: -0.00407179574786
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0261825499774
# Average top: -0.0701597776059
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.23352413283501261, -0.0040717957478648035), mean=-0.070159777605912854, variance=0.0039097689883888795, skewness=-0.7597263701342708, kurtosis=-0.38839829742489407)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0040717957478648035, 0.22510937647281232), mean=0.026182549977359179, variance=0.0023665248785392531, skewness=2.270494467850492, kurtosis=5.144166386006088)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.17460372279
# ####################################
# Sell: 0.286251435816
# ####################################
# Current status
# ####################################
# Status -0.708866924035
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1431
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.23352413283501261, 0.22510937647281232), mean=-0.01767134917950073, variance=0.0041338100654848406, skewness=-0.40651041162076396, kurtosis=2.9489868591165136)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8399.67
# Real price: 8400.01
# Diff: -0.00407179574786
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0257507102925
# Average top: -0.0701597776059
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.23352413283501261, -0.0040717957478648035), mean=-0.070159777605912854, variance=0.0039097689883888795, skewness=-0.7597263701342708, kurtosis=-0.38839829742489407)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0040717957478648035, 0.22510937647281232), mean=0.02575071029248745, variance=0.0023786436169452737, skewness=2.2766590250609244, kurtosis=5.144119662047245)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.17460372279
# ####################################
# Sell: 0.286251435816
# ####################################
# Current status
# ####################################
# Status -0.708866924035
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1432
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.23352413283501261, 0.22510937647281232), mean=-0.017775373839896649, variance=0.0041287804926420342, skewness=-0.40311002468579393, kurtosis=2.9604517676689754)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8399.67
# Real price: 8400.01
# Diff: -0.00407179574786
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0254733111981
# Average top: -0.0701597776059
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.23352413283501261, -0.0040717957478648035), mean=-0.070159777605912854, variance=0.0039097689883888795, skewness=-0.7597263701342708, kurtosis=-0.38839829742489407)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0040717957478648035, 0.22510937647281232), mean=0.025473311198098328, variance=0.00238948542717587, skewness=2.275317226295332, kurtosis=5.124064399888214)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.17460372279
# ####################################
# Sell: 0.286251435816
# ####################################
# Current status
# ####################################
# Status -0.708866924035
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1433
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.23352413283501261, 0.22510937647281232), mean=-0.018047613427185843, variance=0.0041063098334875774, skewness=-0.3996570418131297, kurtosis=3.012495882389838)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8399.67
# Real price: 8400.01
# Diff: -0.00407179574786
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0247473389653
# Average top: -0.0701597776059
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.23352413283501261, -0.0040717957478648035), mean=-0.070159777605912854, variance=0.0039097689883888795, skewness=-0.7597263701342708, kurtosis=-0.38839829742489407)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0040717957478648035, 0.22510937647281232), mean=0.024747338965327145, variance=0.0023923669906468345, skewness=2.3112442231938504, kurtosis=5.242211305564092)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.17460372279
# ####################################
# Sell: 0.286251435816
# ####################################
# Current status
# ####################################
# Status -0.708866924035
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1434
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.23352413283501261, 0.22510937647281232), mean=-0.018260836656183509, variance=0.0040911357318100311, skewness=-0.3952986784238186, kurtosis=3.048738535589332)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8399.67
# Real price: 8400.01
# Diff: -0.00407179574786
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.024178743688
# Average top: -0.0701597776059
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.23352413283501261, -0.0040717957478648035), mean=-0.070159777605912854, variance=0.0039097689883888795, skewness=-0.7597263701342708, kurtosis=-0.38839829742489407)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0040717957478648035, 0.22510937647281232), mean=0.024178743688000034, variance=0.0024006798315199919, skewness=2.331226184432241, kurtosis=5.294904957150159)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.17460372279
# ####################################
# Sell: 0.286251435816
# ####################################
# Current status
# ####################################
# Status -0.708866924035
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1435
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.23352413283501261, 0.76341920318978795), mean=-0.014748650676596677, variance=0.0071176541554716661, skewness=3.705267583628081, kurtosis=35.58457139434318)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8336.46
# Real price: 8273.3
# Diff: 0.76341920319
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0335445729669
# Average top: -0.0701597776059
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.23352413283501261, -0.0040717957478648035), mean=-0.070159777605912854, variance=0.0039097689883888795, skewness=-0.7597263701342708, kurtosis=-0.38839829742489407)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0040717957478648035, 0.76341920318978795), mean=0.033544572966898258, variance=0.0096782888841935068, skewness=5.771087632646786, kurtosis=38.908435345388654)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  True
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.17460372279
# ####################################
# Sell: 0.307084583276
# ####################################
# Current status
# ####################################
# Status -2.20662460195
# ####################################
# Sell at: 8273.3
# 1
# #######################################
# In Cooldown  True
# #######################################
# Minute:  1436
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-0.23352413283501261, 0.79435584421472616), mean=-0.010845219246151751, variance=0.010387981460373034, skewness=4.506445946119731, kurtosis=34.47112538817516)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 8336.7
# Real price: 8271.0
# Diff: 0.794355844215
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0439537234481
# Average top: -0.0701597776059
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-0.23352413283501261, -0.0040717957478648035), mean=-0.070159777605912854, variance=0.0039097689883888795, skewness=-0.7597263701342708, kurtosis=-0.38839829742489407)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.0040717957478648035, 0.79435584421472616), mean=0.043953723448084722, variance=0.017385214468143523, skewness=4.77183863063759, kurtosis=23.615516352226653)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  True
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.17460372279
# ####################################
# Sell: 0.327357147612
# ####################################
# In Cooldown
# ####################################
# Last trade (19L, 8449.48, 'Buy', 19L, datetime.datetime(2018, 3, 26, 8, 16, 21))
# ####################################
# Current decision 20
# ####################################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-dd2e29641164> in <module>()
#     244                 print "Current decision", current_decision
#     245                 print "####################################"
# --> 246     time.sleep(60)
#
# KeyboardInterrupt:
