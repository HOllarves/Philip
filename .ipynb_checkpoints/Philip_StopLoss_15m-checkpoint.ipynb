# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential, load_model
from scipy import stats
from keras.layers import Dense
from keras.layers import LSTM
import numpy as np
from pytz import timezone
from collections import deque
import MySQLdb
import time
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.offline as py
import Queue
est = timezone('US/Eastern')
# Out:
# Using TensorFlow backend.

# %%
btc = pd.read_csv('binance-data_15m.csv')
twitter_sent = pd.read_csv('live_tweet_15m.csv')
reddit_sent = pd.read_csv('live_reddit_15m.csv')

btc.columns = ["Price","Volume", "Number_Trades", "Market_Cap","Supply", "Stamp"]
twitter_sent.columns = ["Sentiment", "Stamp"]
reddit_sent.columns = ["Sentiment", "Stamp"]

merged = pd.merge(twitter_sent, btc,  on='Stamp', how='inner').merge(reddit_sent, on='Stamp', how='inner')
data = merged[["Sentiment_x", "Sentiment_y","Volume", "Market_Cap", "Supply", "Number_Trades", "Price"]].groupby(merged['Stamp']).mean()
datag = data[["Volume", "Market_Cap", "Supply", "Number_Trades", "Price"]]
tw_sentiment = data["Sentiment_x"]
rdt_sentiment = data["Sentiment_y"]

print "Dataset size: " + str(len(datag))
print "Timespan: " + str(len(datag)/60) + " hours"

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
values = datag.values.reshape(-1, datag.shape[1])
tw_sentiment = tw_sentiment.values.reshape(-1, 1)
rdt_sentiment = rdt_sentiment.values.reshape(-1, 1)
tw_sentiment = tw_sentiment.astype('float32')
rdt_sentiment = rdt_sentiment.astype('float32')
values = values.astype('float32')
scaled = scaler.fit_transform(values)
# Out:
# Dataset size: 17586
# Timespan: 293 hours

# %%
train_size = int(len(scaled) * 0.7)
test_size = len(scaled) - train_size
train, test = scaled[0:train_size,:], scaled[train_size:len(scaled),:]
split = train_size

def create_dataset(dataset, look_back, tw_sentiment, rdt_sentiment, sent=False):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        if i >= look_back:
            a = dataset[i-look_back:i+1, 0]
            a = a.tolist()
            if(sent==True):                
                current_tw_sentiment = tw_sentiment[i].tolist()[0]
                current_rdt_sentiment = rdt_sentiment[i].tolist()[0]
                a.append(current_tw_sentiment)
                a.append(current_rdt_sentiment)
            dataX.append(a)
            dataY.append(dataset[i + look_back, 0])
    print(len(dataY))
    return np.array(dataX), np.array(dataY)

look_back = 2
trainX, trainY = create_dataset(train, look_back, tw_sentiment[0:train_size], rdt_sentiment[0:train_size], sent=True)
testX, testY = create_dataset(test, look_back, tw_sentiment[train_size:len(scaled)], rdt_sentiment[train_size:len(scaled)], sent=True)

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# Creating new model
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(100))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
model.save('models/LSTM_Philip_V5_{0}'.format(datetime.now()) + '.h5')

# Loading model
# model = load_model('models/LSTM_12-03-2018_GOOD.h5')

history = model.fit(trainX, trainY, epochs=300, batch_size=100, validation_data=(testX, testY), verbose=0, shuffle=False)
yhat = model.predict(testX)
# yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))
# testY_inverse = scaler.inverse_transform(testY.reshape(-1, 1))
# rmse_sent = sqrt(mean_squared_error(testY_inverse, yhat_inverse))
print "Done"
# print 'Test RMSE: %.3f' % rmse_sent

pyplot.title("Loss")
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# 12306
# 5272
# Done

# %%
#Enter the values for you database connection
dsn_database = "ai_datasets_live" # e.g. "MySQLdbtest"
dsn_hostname = "127.0.0.1"      # e.g.: "mydbinstance.xyz.us-east-1.rds.amazonaws.com"
dsn_port = 3306                 # e.g. 3306 
dsn_uid = "root"                # e.g. "user1"
dsn_pwd = ""                    # e.g. "Password123"

# %%
true_q = Queue.Queue()
pred_q = Queue.Queue()

def process_data(in_data):
    out_data = []
    for line in in_data:
        out_data.append(float(line.split(',')[0]))
    return np.array(out_data).reshape(-1,1)

def get_last_trade():
    conn = MySQLdb.connect(host=dsn_hostname, port=dsn_port, user=dsn_uid, passwd=dsn_pwd, db=dsn_database)
    cursor = conn.cursor()
    cursor.execute ("select * from trades order by date desc limit 1")
    return cursor.fetchone()

class StopLoss():
    
    def __init__(self, buy_price):
        self.balanced_price = buy_price + (buy_price * 0.01)
        self.threshold_price = self.balanced_price
        self.threshold_broken = False
    
    def check(self, new_price):
        if(new_price > self.balanced_price):
            self.threshold_broken = True
        else:
            self.threshold_broken = False
        
        if(self.threshold_broken == True):
            proposed_threshold = new_price - (new_price * 0.01)
            if (proposed_threshold > self.threshold_price):
                self.threshold_price = proposed_threshold
    
    def should_sell(self, next_price):
        if next_price <= self.threshold_price and self.threshold_broken == True:
            return True
        else:
            return False

# %%
diffs = deque([], maxlen=200)
lows = []
tops = []
last_trade = ()
top_lows = deque([], maxlen=30)
top_tops = deque([], maxlen=30)
bought = False
to_db = False
prev = 6819
in_cooldown = False
minute_ = 0
status = 0
current_decision = 0

while True:
    
    # Processing data
    minute_ = minute_ + 1
    btc = open('binance-data_15m.csv','r')
    tw_sent = open('live_tweet_15m.csv','r')
    rdt_sent = open('live_reddit_15m.csv','r')
    bit_data = btc.readlines()
    tw_sent_data = tw_sent.readlines()
    rdt_sent_data = rdt_sent.readlines()
    bit_data = process_data(bit_data[len(bit_data)-5:])
    tw_sent_data = process_data(tw_sent_data[len(tw_sent_data)-5:])
    rdt_sent_data = process_data(rdt_sent_data[len(rdt_sent_data)-5:])
    
    # Last price recieved
    real_price = bit_data[len(bit_data) - 1][0]
    
    # Scaling prices
    live = scaler.fit_transform(bit_data)
    
    # Creating datasets and making prediction
    testX, testY = create_dataset(live, 2, tw_sent_data, rdt_sent_data, sent=True)
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
    yhat = model.predict(testX)
    
    #Re scaling prices
    yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))
    
    # Save real price and prediction price
    true_q.put(bit_data[4])
    pred_q.put(yhat_inverse[0])
    
    # Diference between real price and prediction
    alpha_diff = 100 * ((yhat_inverse[0][0] - float(real_price))/float(real_price))
    diffs.append(alpha_diff)
    diff_analisis = stats.describe(diffs)
    
    print "#######################################"
    print "In Cooldown ", in_cooldown
    print "#######################################"
    print "Minute: ", minute_
    print "#######################################"
    print "Diff analysis ", diff_analisis
    print "#######################################"
    print "########---> Initial values <---#######"
    print "#######################################"
    print "Pred: " + str(yhat_inverse[0][0])
    print "Real price: " + str(real_price)
    print "Diff: " + str(alpha_diff)

    if(len(diffs) >= 200):
        
        # Sorting all diffs
        sorted_diffs = sorted(diffs)
        # Taking the highest 75 (most negative)
        tops = sorted_diffs[0:75]
        # Taking the lowest 75 (most positive)
        lows = sorted_diffs[-75:]
        # Analyzing lists
        low_analisis = stats.describe(lows)
        top_analisis = stats.describe(tops)
        
        # Getting averages of tops and lows
        top_threshold = top_analisis.mean
        low_threshold = low_analisis.mean
        
        print "#######################################"
        print "######---> Averages (Phase 2) <---#####"
        print "#######################################"
        print "Average low: " + str(low_threshold)
        print "Average top: " + str(top_threshold)
        print "#######################################"
        print "#######################################"
        print "Top analysis", top_analisis
        print "#######################################"
        print "#######################################"
        print "Low analysis", low_analisis
        print "#######################################"
        print "#######################################"
        print "Low length", len(top_lows)
        print "Top length", len(top_tops)
        print "#######################################"
        print "#######################################"
        print "Low break: ", alpha_diff > low_threshold
        print "#######################################"
        print "Top break: ", alpha_diff < top_threshold 
        
        # If diff is greater than the average low
        if(alpha_diff > low_threshold):
            # Adding to top_lows list
            top_lows.append(alpha_diff)
            # Sorting
            sorted_lows = sorted(top_lows)
            top_lows = deque(sorted_lows, maxlen=30)
            
        # If diff is lower than the average high
        if(alpha_diff < top_threshold):
            # Adding to top_tops list
            top_tops.append(alpha_diff)            
            # Sorting 
            sorted_tops = sorted(top_tops)
            top_tops = deque(sorted_tops, maxlen=30)
             
        if(len(top_tops) >= 30 and len(top_lows) >= 30):
            # Analyzing top_tops and top_lows
            alpha_top_analisis = stats.describe(top_tops)
            alpha_low_analisis = stats.describe(top_lows)

            # Getting averages of top_tops and top_lows analisis
            alpha_top = alpha_top_analisis.mean
            alpha_low = alpha_low_analisis.mean

            print "####################################"
            print "####---> Signals (Phase 3) <---#####"
            print "Buy: " + str(alpha_top - alpha_top_analisis.variance)
            print "####################################"
            print "Sell: " + str(alpha_low)

            if(not in_cooldown):
                
                if bought:
                    status = ((real_price - buy_price) / buy_price) * 100
                    print "####################################"
                    print "Current status"
                    print "####################################"
                    print "Status", status
                    print "####################################"
                    
                    if('stop_loss' in locals() and isinstance(stop_loss, StopLoss)):
                        stop_loss.check(real_price)
                        print "Current status"
                        print "####################################"
                        print "Current stop_loss", stop_loss.threshold_price
                        print "####################################"
                    
                    if status >= 0.15:
                        alpha_low = 0.05
                    else:
                        alpha_low = alpha_low_analisis.mean
                        
                # If difference is lower that than the lowest top (negative value) -> BUY
                if alpha_diff < alpha_top  and not bought:
                    decision = 1
                    print "Buy at: " + str(real_price)
                    bought = True
                    to_db = True
                    in_cooldown = True

                elif 'stop_loss' in locals() and isinstance(stop_loss, StopLoss) and bought and stop_loss.should_sell(real_price):
                    decision = 2
                    print "Sell at: " + str(real_price)
                    bought = False
                    to_db = True
                    in_cooldown = True
                    buy_price = 0
                    del stop_loss
                # If difference is greater than the average low in the top_lows list -> SELL
                elif alpha_diff > alpha_low and bought:
                    decision = 2
                    print "Sell at: " + str(real_price)
                    bought = False
                    to_db = True
                    in_cooldown = True
                    buy_price = 0
                    del stop_loss
                    
                    # Saving decision to DB
                if to_db == True:
                    conn = MySQLdb.connect(host=dsn_hostname, port=dsn_port, user=dsn_uid, passwd=dsn_pwd, db=dsn_database)
                    cursor=conn.cursor()
                    input_string = "INSERT INTO live_data (yhat, bit_data, sent_data, reddit_sent, date, decision) values ({},{},{},{},'{}',{});".format(
                        yhat_inverse[0][0],
                        bit_data[0][0],
                        tw_sent_data[4][0],
                        rdt_sent_data[4][0],
                        datetime.now(tz=est).strftime('%Y-%m-%d %H:%M:%S'),
                        decision)
                    cursor.execute(input_string)
                    current_decision = cursor.lastrowid
                    conn.commit()
                    cursor.close()
                    to_db = False
            else:
                last_trade = get_last_trade()
                if last_trade and len(last_trade) is not 0 and current_decision == last_trade[3]:
                    in_cooldown = False
                    if(last_trade[2] == "Buy"):
                        buy_price = last_trade[1]
                        stop_loss = StopLoss(buy_price)
                        
                print "####################################"
                print "In Cooldown"
                print "####################################"
                print "Last trade", last_trade
                print "####################################"
                print "Current decision", current_decision
                print "####################################"
    time.sleep(60)
# Out:
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1
# #######################################
# Diff analysis  DescribeResult(nobs=1, minmax=(-0.16386128257862659, -0.16386128257862659), mean=-0.16386128257862659, variance=nan, skewness=0.0, kurtosis=-3.0)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6827.63
# Real price: 6838.84
# Diff: -0.163861282579
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  2
# #######################################
# Diff analysis  DescribeResult(nobs=2, minmax=(-0.16386128257862659, 0.017302531306709865), mean=-0.073279375635958363, variance=0.016410163730740411, skewness=0.0, kurtosis=-2.0)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6827.99
# Real price: 6826.81
# Diff: 0.0173025313067
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  3
# #######################################
# Diff analysis  DescribeResult(nobs=3, minmax=(-0.16386128257862659, 0.057093392740753666), mean=-0.02982178617705435, variance=0.013870768110106138, skewness=-0.6173900284553298, kurtosis=-1.4999999999999998)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6831.05
# Real price: 6827.15
# Diff: 0.0570933927408
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  4
# #######################################
# Diff analysis  DescribeResult(nobs=4, minmax=(-0.26579461492084044, 0.057093392740753666), mean=-0.088814993363000874, variance=0.023167972716406814, skewness=-0.18170004422848665, kurtosis=-1.6811162732360734)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6827.73
# Real price: 6845.93
# Diff: -0.265794614921
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  5
# #######################################
# Diff analysis  DescribeResult(nobs=5, minmax=(-0.26579461492084044, 0.057093392740753666), mean=-0.10521144081438458, variance=0.018720196982435044, skewness=0.16256062043634015, kurtosis=-1.5602812575815928)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6827.17
# Real price: 6838.85
# Diff: -0.17079723062
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  6
# #######################################
# Diff analysis  DescribeResult(nobs=6, minmax=(-0.26579461492084044, 0.057093392740753666), mean=-0.11338235245131463, variance=0.015376740367819153, skewness=0.37454614065688085, kurtosis=-1.278463373834451)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6829.45
# Real price: 6840.0
# Diff: -0.154236910636
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  7
# #######################################
# Diff analysis  DescribeResult(nobs=7, minmax=(-0.48129497210132571, 0.057093392740753666), mean=-0.16594129811560193, variance=0.032151049691906491, skewness=-0.47176476919328064, kurtosis=-0.44337193608279835)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6831.98
# Real price: 6865.02
# Diff: -0.481294972101
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  8
# #######################################
# Diff analysis  DescribeResult(nobs=8, minmax=(-0.48129497210132571, 0.057093392740753666), mean=-0.1847043803361102, variance=0.030374468628371131, skewness=-0.186613100288828, kurtosis=-0.670595316858416)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6840.0
# Real price: 6861.69
# Diff: -0.31604595588
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  9
# #######################################
# Diff analysis  DescribeResult(nobs=9, minmax=(-0.48129497210132571, 0.057093392740753666), mean=-0.18304348834930104, variance=0.026602487109551366, skewness=-0.2299577083092015, kurtosis=-0.37506393450037034)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6842.6
# Real price: 6854.24
# Diff: -0.169756352455
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  10
# #######################################
# Diff analysis  DescribeResult(nobs=10, minmax=(-0.48129497210132571, 0.057093392740753666), mean=-0.18211946748761793, variance=0.023655193354018354, skewness=-0.2612388051083675, kurtosis=-0.07913093939726767)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6848.51
# Real price: 6860.43
# Diff: -0.173803279732
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  11
# #######################################
# Diff analysis  DescribeResult(nobs=11, minmax=(-0.48129497210132571, 0.057093392740753666), mean=-0.17657239372180086, variance=0.021628144319614101, skewness=-0.37883250060406354, kurtosis=0.16699357431228945)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6854.5
# Real price: 6862.81
# Diff: -0.121101656064
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  12
# #######################################
# Diff analysis  DescribeResult(nobs=12, minmax=(-0.48129497210132571, 0.057093392740753666), mean=-0.17642166734180029, variance=0.019662222002766901, skewness=-0.3990373380162352, kurtosis=0.4565907270119136)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6855.79
# Real price: 6867.79
# Diff: -0.174763677162
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  13
# #######################################
# Diff analysis  DescribeResult(nobs=13, minmax=(-0.48129497210132571, 0.069762060359919054), mean=-0.15748445751859108, variance=0.022685736409083574, skewness=-0.31021165261246403, kurtosis=0.0673727149755865)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6855.27
# Real price: 6850.49
# Diff: 0.0697620603599
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  14
# #######################################
# Diff analysis  DescribeResult(nobs=14, minmax=(-0.48129497210132571, 0.069762060359919054), mean=-0.14182895083072625, variance=0.02437200821738392, skewness=-0.348816840372156, kurtosis=-0.15940229909160264)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6855.23
# Real price: 6851.0
# Diff: 0.0616926361115
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  15
# #######################################
# Diff analysis  DescribeResult(nobs=15, minmax=(-0.48129497210132571, 0.087396247661014781), mean=-0.12654727093127685, variance=0.026134096595809318, skewness=-0.374655075421606, kurtosis=-0.3192442240994273)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6851.91
# Real price: 6845.93
# Diff: 0.087396247661
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  16
# #######################################
# Diff analysis  DescribeResult(nobs=16, minmax=(-0.48129497210132571, 0.087396247661014781), mean=-0.11553053825771203, variance=0.026333717870234686, skewness=-0.46738863959390636, kurtosis=-0.34614690103241674)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6843.4
# Real price: 6840.0
# Diff: 0.0497204518458
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  17
# #######################################
# Diff analysis  DescribeResult(nobs=17, minmax=(-0.48129497210132571, 0.087396247661014781), mean=-0.10563434264672578, variance=0.02635275019205038, skewness=-0.5539012492519066, kurtosis=-0.3331939615179844)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6843.67
# Real price: 6840.06
# Diff: 0.0527047871291
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  18
# #######################################
# Diff analysis  DescribeResult(nobs=18, minmax=(-0.48129497210132571, 0.087396247661014781), mean=-0.11366467419658791, variance=0.025963340462460214, skewness=-0.42188299853108063, kurtosis=-0.48514883979220524)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6840.8
# Real price: 6857.96
# Diff: -0.250180310544
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  19
# #######################################
# Diff analysis  DescribeResult(nobs=19, minmax=(-0.48129497210132571, 0.087396247661014781), mean=-0.11766265313443025, variance=0.024824625535151395, skewness=-0.35368291831243936, kurtosis=-0.44777902252255153)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6839.85
# Real price: 6852.84
# Diff: -0.189626274016
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  20
# #######################################
# Diff analysis  DescribeResult(nobs=20, minmax=(-0.48129497210132571, 0.087396247661014781), mean=-0.12594906948856563, variance=0.02489136021634087, skewness=-0.23403223828120792, kurtosis=-0.6021369472819589)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6842.55
# Real price: 6862.0
# Diff: -0.283390980217
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  21
# #######################################
# Diff analysis  DescribeResult(nobs=21, minmax=(-0.48129497210132571, 0.087396247661014781), mean=-0.13131056842365649, variance=0.024250451292974408, skewness=-0.14439553277224035, kurtosis=-0.619530888747275)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6845.63
# Real price: 6862.0
# Diff: -0.238540547125
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  22
# #######################################
# Diff analysis  DescribeResult(nobs=22, minmax=(-0.48129497210132571, 0.087396247661014781), mean=-0.13838716706968865, variance=0.024197389362805393, skewness=-0.04688735124837476, kurtosis=-0.6997887102798113)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6855.27
# Real price: 6875.0
# Diff: -0.286995738636
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  23
# #######################################
# Diff analysis  DescribeResult(nobs=23, minmax=(-0.51218867907415466, 0.087396247661014781), mean=-0.15463940672205673, variance=0.029172619783646551, skewness=-0.2281577343489767, kurtosis=-0.5480196289115309)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6855.71
# Real price: 6891.0
# Diff: -0.512188679074
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  24
# #######################################
# Diff analysis  DescribeResult(nobs=24, minmax=(-0.51218867907415466, 0.087396247661014781), mean=-0.16461905507034347, variance=0.030294486158175621, skewness=-0.14585270194911631, kurtosis=-0.7213149613302603)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6863.68
# Real price: 6890.84
# Diff: -0.394150967081
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  25
# #######################################
# Diff analysis  DescribeResult(nobs=25, minmax=(-0.51218867907415466, 0.087396247661014781), mean=-0.17764801866979926, variance=0.03327606321348358, skewness=-0.14433923299554363, kurtosis=-0.8259835750529949)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6869.69
# Real price: 6903.54
# Diff: -0.490343145057
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  26
# #######################################
# Diff analysis  DescribeResult(nobs=26, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.19118701695641194, variance=0.03671093702467166, skewness=-0.15589154859410728, kurtosis=-0.8901287518255532)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6880.36
# Real price: 6917.0
# Diff: -0.529661974122
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  27
# #######################################
# Diff analysis  DescribeResult(nobs=27, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.1863026635471938, variance=0.035943114430443943, skewness=-0.22019784239972875, kurtosis=-0.8584673378701173)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6892.6
# Real price: 6896.69
# Diff: -0.0593094749075
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  28
# #######################################
# Diff analysis  DescribeResult(nobs=28, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.18066329508933138, variance=0.035502357314956066, skewness=-0.2851221067535499, kurtosis=-0.8410306140720598)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6897.92
# Real price: 6899.88
# Diff: -0.028400346727
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  29
# #######################################
# Diff analysis  DescribeResult(nobs=29, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.17553746651053884, variance=0.034996365422234887, skewness=-0.3461859553213101, kurtosis=-0.8115393483120013)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6897.79
# Real price: 6900.0
# Diff: -0.0320142663043
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  30
# #######################################
# Diff analysis  DescribeResult(nobs=30, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.1675344937958117, variance=0.035711021368958512, skewness=-0.38144868561048434, kurtosis=-0.8256137181588619)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6886.64
# Real price: 6882.2
# Diff: 0.0645517149313
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  31
# #######################################
# Diff analysis  DescribeResult(nobs=31, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.16264919999310973, variance=0.035260502951693501, skewness=-0.4371964448892419, kurtosis=-0.7898088893839432)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6887.83
# Real price: 6888.94
# Diff: -0.0160903859121
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  32
# #######################################
# Diff analysis  DescribeResult(nobs=32, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.16076958554224952, variance=0.034236121788090858, skewness=-0.47183185165397795, kurtosis=-0.7143436375431671)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6882.89
# Real price: 6889.95
# Diff: -0.102501537566
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  33
# #######################################
# Diff analysis  DescribeResult(nobs=33, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.15798941103721875, variance=0.033421312201400974, skewness=-0.5159955534577599, kurtosis=-0.6462698322743115)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6883.27
# Real price: 6888.02
# Diff: -0.0690238268762
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  34
# #######################################
# Diff analysis  DescribeResult(nobs=34, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.15215966862571417, variance=0.033564065648867727, skewness=-0.5549210998221612, kurtosis=-0.6308353058167748)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6884.77
# Real price: 6882.0
# Diff: 0.0402218309539
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  35
# #######################################
# Diff analysis  DescribeResult(nobs=35, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.14990470525975158, variance=0.032754857339794614, skewness=-0.5938917161897207, kurtosis=-0.5574177834571246)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6884.63
# Real price: 6889.68
# Diff: -0.073235950817
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  36
# #######################################
# Diff analysis  DescribeResult(nobs=36, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.14687145883752376, variance=0.032150225291829822, skewness=-0.6379624310428117, kurtosis=-0.49307197037143036)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6882.2
# Real price: 6885.0
# Diff: -0.0407078340595
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  37
# #######################################
# Diff analysis  DescribeResult(nobs=37, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.14505951364970404, variance=0.031378639856623411, skewness=-0.6725946358619602, kurtosis=-0.4155061414316439)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6882.57
# Real price: 6888.07
# Diff: -0.0798294868882
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  38
# #######################################
# Diff analysis  DescribeResult(nobs=38, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.14284773351612659, variance=0.030716463420800047, skewness=-0.7107941164293401, kurtosis=-0.34083683528663666)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6883.58
# Real price: 6887.78
# Diff: -0.0610118685738
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  39
# #######################################
# Diff analysis  DescribeResult(nobs=39, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.13977221393844155, variance=0.030277029442278384, skewness=-0.7519576170627833, kurtosis=-0.2789241729910401)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6885.3
# Real price: 6886.88
# Diff: -0.0229024699864
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  40
# #######################################
# Diff analysis  DescribeResult(nobs=40, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.13661627395452605, variance=0.029899093641297902, skewness=-0.7917210100788844, kurtosis=-0.2190745812531727)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6886.07
# Real price: 6887.0
# Diff: -0.0135346145818
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  41
# #######################################
# Diff analysis  DescribeResult(nobs=41, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.13261159443540424, variance=0.029809152080351269, skewness=-0.8238753745943184, kurtosis=-0.17887747191624026)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6883.27
# Real price: 6881.37
# Diff: 0.0275755863295
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  42
# #######################################
# Diff analysis  DescribeResult(nobs=42, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.12792985114063649, variance=0.030002685842266917, skewness=-0.8417549734051897, kurtosis=-0.15558160786967123)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6875.4
# Real price: 6871.0
# Diff: 0.0640216239448
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  43
# #######################################
# Diff analysis  DescribeResult(nobs=43, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.1230246211469858, variance=0.030322971274852051, skewness=-0.8512160293801244, kurtosis=-0.13854920700068396)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6874.71
# Real price: 6869.01
# Diff: 0.0829950385863
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  44
# #######################################
# Diff analysis  DescribeResult(nobs=44, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.1213249255129128, variance=0.029744900367300538, skewness=-0.8835335711280472, kurtosis=-0.0614985972252029)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6871.04
# Real price: 6874.36
# Diff: -0.0482380132478
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  45
# #######################################
# Diff analysis  DescribeResult(nobs=45, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.11960707370176354, variance=0.029201675572435429, skewness=-0.9158014675110038, kurtosis=0.015608790520164728)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6869.13
# Real price: 6872.16
# Diff: -0.0440215940112
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  46
# #######################################
# Diff analysis  DescribeResult(nobs=46, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.11947861030756726, variance=0.028553508579411364, skewness=-0.9281891590192717, kurtosis=0.08530866861984521)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6870.15
# Real price: 6877.97
# Diff: -0.113697757569
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  47
# #######################################
# Diff analysis  DescribeResult(nobs=47, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.11665839965182043, variance=0.0283065987747439, skewness=-0.9597906549772446, kurtosis=0.14155330150934065)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6870.38
# Real price: 6869.48
# Diff: 0.0130712905125
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  48
# #######################################
# Diff analysis  DescribeResult(nobs=48, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.1134031287973621, variance=0.028212976555829317, skewness=-0.985289998096328, kurtosis=0.18491135189769414)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6866.72
# Real price: 6864.0
# Diff: 0.0395946013622
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  49
# #######################################
# Diff analysis  DescribeResult(nobs=49, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10965225653587331, variance=0.028314589304294504, skewness=-0.9995144567619924, kurtosis=0.21214184832654892)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6868.83
# Real price: 6864.0
# Diff: 0.0703896120156
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  50
# #######################################
# Diff analysis  DescribeResult(nobs=50, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10998721955298066, variance=0.02774235055412385, skewness=-1.0032823449810142, kurtosis=0.2681950595587481)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6864.31
# Real price: 6873.0
# Diff: -0.126400407391
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  51
# #######################################
# Diff analysis  DescribeResult(nobs=51, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10812103610868427, variance=0.027365118216077428, skewness=-1.0337515462210363, kurtosis=0.3389945771645735)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6863.99
# Real price: 6865.01
# Diff: -0.0148118638939
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  52
# #######################################
# Diff analysis  DescribeResult(nobs=52, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10598105459603337, variance=0.027066682356137507, skewness=-1.0633704098752148, kurtosis=0.4038392218533171)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6865.22
# Real price: 6865.0
# Diff: 0.00315800254916
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  53
# #######################################
# Diff analysis  DescribeResult(nobs=53, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10547746149896174, variance=0.026559610352297258, skewness=-1.0820052794658872, kurtosis=0.4792447141827907)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6864.55
# Real price: 6870.0
# Diff: -0.0792906204512
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  54
# #######################################
# Diff analysis  DescribeResult(nobs=54, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.1048807660049569, variance=0.026077712086347557, skewness=-1.1019954969639614, kurtosis=0.5560532176676936)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6864.99
# Real price: 6870.02
# Diff: -0.0732559048227
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  55
# #######################################
# Diff analysis  DescribeResult(nobs=55, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10757845027350224, variance=0.025995054014857577, skewness=-1.0504666720493605, kurtosis=0.4520901609347261)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6865.56
# Real price: 6882.99
# Diff: -0.253253400775
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  56
# #######################################
# Diff analysis  DescribeResult(nobs=56, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10913213189958489, variance=0.025657596558465588, skewness=-1.0251846144672803, kurtosis=0.4388174182959359)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6866.62
# Real price: 6880.01
# Diff: -0.194584621334
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  57
# #######################################
# Diff analysis  DescribeResult(nobs=57, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.11056127381674155, variance=0.025315844648654461, skewness=-1.0024022830404298, kurtosis=0.43252725721296326)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6871.87
# Real price: 6884.99
# Diff: -0.190593221178
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  58
# #######################################
# Diff analysis  DescribeResult(nobs=58, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10984165863965245, variance=0.024901742091419099, skewness=-1.0228009882938367, kurtosis=0.503106728908862)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6874.27
# Real price: 6879.0
# Diff: -0.0688235935456
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  59
# #######################################
# Diff analysis  DescribeResult(nobs=59, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10805908644515401, variance=0.024659877964619905, skewness=-1.0489633780793701, kurtosis=0.5603082076346504)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6879.68
# Real price: 6880.0
# Diff: -0.00466989916424
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  60
# #######################################
# Diff analysis  DescribeResult(nobs=60, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10695512770040648, variance=0.024315037425927527, skewness=-1.0731559719859505, kurtosis=0.6298104728853602)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6879.13
# Real price: 6882.01
# Diff: -0.0418215617603
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  61
# #######################################
# Diff analysis  DescribeResult(nobs=61, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10658626179148034, variance=0.023918086587746908, skewness=-1.0886617243945556, kurtosis=0.6981919436061581)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6879.2
# Real price: 6885.01
# Diff: -0.0844543072559
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  62
# #######################################
# Diff analysis  DescribeResult(nobs=62, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10427775158564112, variance=0.023856398408588674, skewness=-1.106883170834127, kurtosis=0.7330582504624839)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6877.53
# Real price: 6875.02
# Diff: 0.0365413709706
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  63
# #######################################
# Diff analysis  DescribeResult(nobs=63, minmax=(-0.529661974121729, 0.087396247661014781), mean=-0.10167868897565671, variance=0.023897190755484302, skewness=-1.1176292300520208, kurtosis=0.7540394647166169)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6874.51
# Real price: 6870.42
# Diff: 0.0594631928434
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  64
# #######################################
# Diff analysis  DescribeResult(nobs=64, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.096104908159124564, variance=0.025506160353109472, skewness=-0.9246405205572863, kurtosis=0.7662615005019098)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6846.63
# Real price: 6829.21
# Diff: 0.255043283282
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  65
# #######################################
# Diff analysis  DescribeResult(nobs=65, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.09186757592773398, variance=0.026274700586138931, skewness=-0.8722472071589885, kurtosis=0.7128807389687029)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6842.71
# Real price: 6830.46
# Diff: 0.179321686881
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  66
# #######################################
# Diff analysis  DescribeResult(nobs=66, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.08939018940764594, variance=0.026275545725289576, skewness=-0.8889792931970792, kurtosis=0.7241707456763371)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6830.91
# Real price: 6826.02
# Diff: 0.0716399343981
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  67
# #######################################
# Diff analysis  DescribeResult(nobs=67, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.090825683458939252, variance=0.026015494488595518, skewness=-0.8649028145530727, kurtosis=0.7110166569858762)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6827.31
# Real price: 6840.0
# Diff: -0.185568290844
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  68
# #######################################
# Diff analysis  DescribeResult(nobs=68, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.093238416182260003, variance=0.026023050511283601, skewness=-0.8221396469564451, kurtosis=0.6179860623125046)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6826.02
# Real price: 6843.46
# Diff: -0.254891508645
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  69
# #######################################
# Diff analysis  DescribeResult(nobs=69, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.094111247229561365, variance=0.025692925140562206, skewness=-0.8099523899729714, kurtosis=0.638530741207433)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6828.49
# Real price: 6838.99
# Diff: -0.153463758446
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  70
# #######################################
# Diff analysis  DescribeResult(nobs=70, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.093133995250675408, variance=0.025387415406757572, skewness=-0.8299582155217543, kurtosis=0.6926278701721409)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6831.85
# Real price: 6833.61
# Diff: -0.0257036087075
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  71
# #######################################
# Diff analysis  DescribeResult(nobs=71, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.090281255308800143, variance=0.025602544931297794, skewness=-0.8324200078759522, kurtosis=0.673288340864425)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6828.44
# Real price: 6820.98
# Diff: 0.109410540622
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  72
# #######################################
# Diff analysis  DescribeResult(nobs=72, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.088689061197994731, variance=0.025424471617140128, skewness=-0.854147681910274, kurtosis=0.7092970723981424)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6826.65
# Real price: 6824.99
# Diff: 0.0243567206692
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  73
# #######################################
# Diff analysis  DescribeResult(nobs=73, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.090788700231985098, variance=0.025393173293124054, skewness=-0.8164015691796572, kurtosis=0.6337652219180194)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6821.45
# Real price: 6838.0
# Diff: -0.241962710679
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  74
# #######################################
# Diff analysis  DescribeResult(nobs=74, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.095383818512765076, variance=0.026607839893239657, skewness=-0.7904731251102983, kurtosis=0.43134294288692)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6823.49
# Real price: 6853.01
# Diff: -0.43082745301
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  75
# #######################################
# Diff analysis  DescribeResult(nobs=75, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.096573766969847818, variance=0.02635447278906548, skewness=-0.7711129479415365, kurtosis=0.4279043643678966)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6824.43
# Real price: 6837.05
# Diff: -0.184629952794
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  76
# #######################################
# Diff analysis  DescribeResult(nobs=76, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.097748037022457573, variance=0.026107876990435274, skewness=-0.7518815564108551, kurtosis=0.4247135371211539)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6832.53
# Real price: 6845.25
# Diff: -0.185818290968
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  77
# #######################################
# Diff analysis  DescribeResult(nobs=77, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.097851742146897736, variance=0.025765180409161009, skewness=-0.7548261859056363, kurtosis=0.4675865697437085)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6836.85
# Real price: 6844.09
# Diff: -0.105733331604
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  78
# #######################################
# Diff analysis  DescribeResult(nobs=78, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.09740640679847036, variance=0.025446036915234102, skewness=-0.7673137046985095, kurtosis=0.5169569259992048)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6838.13
# Real price: 6842.45
# Diff: -0.0631155849696
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  79
# #######################################
# Diff analysis  DescribeResult(nobs=79, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.096948178647500591, variance=0.025136393542760049, skewness=-0.7800249412796295, kurtosis=0.5664062894797488)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6839.81
# Real price: 6844.0
# Diff: -0.0612063828719
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  80
# #######################################
# Diff analysis  DescribeResult(nobs=80, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.096897452398536324, variance=0.02481841719820297, skewness=-0.7859083714746314, kurtosis=0.6125087506784155)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6842.65
# Real price: 6849.01
# Diff: -0.0928900787304
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  81
# #######################################
# Diff analysis  DescribeResult(nobs=81, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.096948709406862954, variance=0.024508399792978544, skewness=-0.7898066202105837, kurtosis=0.6565601291364369)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6843.08
# Real price: 6850.0
# Diff: -0.101049270073
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  82
# #######################################
# Diff analysis  DescribeResult(nobs=82, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.099557484282032774, variance=0.024763894876672219, skewness=-0.7491158516806137, kurtosis=0.5277714541553666)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6843.65
# Real price: 6864.99
# Diff: -0.310868249171
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  83
# #######################################
# Diff analysis  DescribeResult(nobs=83, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.10085111403338556, variance=0.024600794827151579, skewness=-0.7263376593209235, kurtosis=0.508774180658818)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6845.8
# Real price: 6860.0
# Diff: -0.206928753644
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  84
# #######################################
# Diff analysis  DescribeResult(nobs=84, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.10083217905111276, variance=0.024304429825570673, skewness=-0.7310652749748503, kurtosis=0.551396983242955)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6851.48
# Real price: 6858.29
# Diff: -0.0992605755225
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  85
# #######################################
# Diff analysis  DescribeResult(nobs=85, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.10059920122005353, variance=0.024019705062196285, skewness=-0.7397036361688832, kurtosis=0.5967588317615808)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6854.44
# Real price: 6860.0
# Diff: -0.0810290634111
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  86
# #######################################
# Diff analysis  DescribeResult(nobs=86, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.10012120100088072, variance=0.023756769938778205, skewness=-0.7522529820286507, kurtosis=0.642444468503744)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6858.38
# Real price: 6862.46
# Diff: -0.0594911823712
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  87
# #######################################
# Diff analysis  DescribeResult(nobs=87, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.099829493705323472, variance=0.023487931531588652, skewness=-0.7619463562315011, kurtosis=0.6882976055583989)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6858.89
# Real price: 6864.02
# Diff: -0.0747426662874
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  88
# #######################################
# Diff analysis  DescribeResult(nobs=88, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.099295165088538875, variance=0.023243079929310552, skewness=-0.7753061690458795, kurtosis=0.7335928743315248)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6859.39
# Real price: 6863.01
# Diff: -0.0528085754283
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  89
# #######################################
# Diff analysis  DescribeResult(nobs=89, minmax=(-0.529661974121729, 0.25504328328239967), mean=-0.09879253284477213, variance=0.023001438907373117, skewness=-0.788261439660522, kurtosis=0.7791704625485862)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6861.25
# Real price: 6865.0
# Diff: -0.0545608953933
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  90
# #######################################
# ...
# ####################################
# Current status
# ####################################
# Status 0.314220022649
# ####################################
# Current status
# ####################################
# Current stop_loss 6769.3331
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1567
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-1.084780742037172, 0.34488624379210969), mean=-0.10869817047794911, variance=0.038995088478885429, skewness=-1.4516340556186822, kurtosis=4.161804397893203)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6722.23
# Real price: 6724.0
# Diff: -0.0263093838303
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.063649370039
# Average top: -0.295008896351
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-1.084780742037172, -0.13741199794254214), mean=-0.29500889635089411, variance=0.033393850173470706, skewness=-2.177724871369322, kurtosis=5.02920764646384)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.041898133823139047, 0.34488624379210969), mean=0.063649370039033787, variance=0.0053202437487709798, skewness=1.1737353032218434, kurtosis=1.8297621519973033)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.280813763204
# ####################################
# Sell: 0.222736802814
# ####################################
# Current status
# ####################################
# Status 0.323619766916
# ####################################
# Current status
# ####################################
# Current stop_loss 6769.3331
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1568
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-1.084780742037172, 0.34488624379210969), mean=-0.10753057256918637, variance=0.038995978116826646, skewness=-1.467284029374083, kurtosis=4.196096867625442)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6720.61
# Real price: 6720.0
# Diff: 0.00902448381696
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0643283382742
# Average top: -0.293817699345
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-1.084780742037172, -0.1351553225306629), mean=-0.29381769934549523, variance=0.033670533254865562, skewness=-2.162321445111434, kurtosis=4.961652073414313)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.034553532137279887, 0.34488624379210969), mean=0.064328338274235161, variance=0.0052095549350332452, skewness=1.2195750403731938, kurtosis=1.9323062871610626)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.280813763204
# ####################################
# Sell: 0.222736802814
# ####################################
# Current status
# ####################################
# Status 0.263938850933
# ####################################
# Current status
# ####################################
# Current stop_loss 6769.3331
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1569
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-1.084780742037172, 0.34488624379210969), mean=-0.10713932669567226, variance=0.039018344867150515, skewness=-1.4717754119322437, kurtosis=4.199585091565481)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6721.32
# Real price: 6723.99
# Diff: -0.0397692743631
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0643283382742
# Average top: -0.293817699345
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-1.084780742037172, -0.1351553225306629), mean=-0.29381769934549523, variance=0.033670533254865562, skewness=-2.162321445111434, kurtosis=4.961652073414313)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.034553532137279887, 0.34488624379210969), mean=0.064328338274235161, variance=0.0052095549350332452, skewness=1.2195750403731938, kurtosis=1.9323062871610626)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.280813763204
# ####################################
# Sell: 0.222736802814
# ####################################
# Current status
# ####################################
# Status 0.323470564626
# ####################################
# Current status
# ####################################
# Current stop_loss 6769.3331
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1570
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-1.084780742037172, 0.34488624379210969), mean=-0.10802092051058132, variance=0.038922766553885484, skewness=-1.4656525739191677, kurtosis=4.207265947024379)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6720.41
# Real price: 6729.95
# Diff: -0.141802862113
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0633378692711
# Average top: -0.293906333207
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-1.084780742037172, -0.13741199794254214), mean=-0.29390633320658832, variance=0.033642616656558794, skewness=-2.164615083509541, kurtosis=4.969450424104483)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.039769274363135307, 0.34488624379210969), mean=0.06333786927113777, variance=0.0053429867508347564, skewness=1.1767322168675158, kurtosis=1.8080819102122598)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.280813763204
# ####################################
# Sell: 0.222736802814
# ####################################
# Current status
# ####################################
# Status 0.41239512944
# ####################################
# Current status
# ####################################
# Current stop_loss 6769.3331
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1571
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-1.084780742037172, 0.34488624379210969), mean=-0.10810226432160693, variance=0.038913686666756625, skewness=-1.4650247472699731, kurtosis=4.208168314045954)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6721.22
# Real price: 6725.3
# Diff: -0.0606632441118
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0633378692711
# Average top: -0.293906333207
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-1.084780742037172, -0.13741199794254214), mean=-0.29390633320658832, variance=0.033642616656558794, skewness=-2.164615083509541, kurtosis=4.969450424104483)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.039769274363135307, 0.34488624379210969), mean=0.06333786927113777, variance=0.0053429867508347564, skewness=1.1767322168675158, kurtosis=1.8080819102122598)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.280813763204
# ####################################
# Sell: 0.222736802814
# ####################################
# Current status
# ####################################
# Status 0.343016064611
# ####################################
# Current status
# ####################################
# Current stop_loss 6769.3331
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1572
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-1.084780742037172, 0.34488624379210969), mean=-0.10731292836104407, variance=0.038901901700391615, skewness=-1.4770655202978444, kurtosis=4.236050780362429)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6722.57
# Real price: 6725.0
# Diff: -0.0362017890335
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0633854357422
# Average top: -0.293120817758
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-1.084780742037172, -0.1351553225306629), mean=-0.2931208177583835, variance=0.033847861371899476, skewness=-2.1512851904073638, kurtosis=4.916376379543413)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.036201789033457249, 0.34488624379210969), mean=0.063385435742200139, variance=0.0053332150050819085, skewness=1.1818389878072457, kurtosis=1.8154647849962116)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.280813763204
# ####################################
# Sell: 0.222736802814
# ####################################
# Current status
# ####################################
# Status 0.338539995912
# ####################################
# Current status
# ####################################
# Current stop_loss 6769.3331
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1573
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-1.084780742037172, 0.34488624379210969), mean=-0.10826193891163159, variance=0.039219377557023122, skewness=-1.4561516315682475, kurtosis=4.106592138857745)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6725.08
# Real price: 6750.0
# Diff: -0.369118923611
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.0633854357422
# Average top: -0.29565151256
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-1.084780742037172, -0.1351553225306629), mean=-0.29565151255995026, variance=0.033744402310995472, skewness=-2.123774125991092, kurtosis=4.844402121720885)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.036201789033457249, 0.34488624379210969), mean=0.063385435742200139, variance=0.0053332150050819085, skewness=1.1818389878072457, kurtosis=1.8154647849962116)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  True
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.282747369023
# ####################################
# Sell: 0.222736802814
# ####################################
# Current status
# ####################################
# Status 0.711545720804
# ####################################
# Current status
# ####################################
# Current stop_loss 6769.3331
# ####################################
# 1
# #######################################
# In Cooldown  False
# #######################################
# Minute:  1574
# #######################################
# Diff analysis  DescribeResult(nobs=200, minmax=(-1.084780742037172, 0.34488624379210969), mean=-0.10742122821443227, variance=0.039229613222005605, skewness=-1.4675634383332836, kurtosis=4.127856733686466)
# #######################################
# ########---> Initial values <---#######
# #######################################
# Pred: 6724.81
# Real price: 6726.0
# Diff: -0.0177134440975
# #######################################
# ######---> Averages (Phase 2) <---#####
# #######################################
# Average low: 0.063631947008
# Average top: -0.2949684763
# #######################################
# #######################################
# Top analysis DescribeResult(nobs=75, minmax=(-1.084780742037172, -0.1346278640523853), mean=-0.29496847630015005, variance=0.033931408783412331, skewness=-2.111233589251784, kurtosis=4.795884539645674)
# #######################################
# #######################################
# Low analysis DescribeResult(nobs=75, minmax=(-0.034553532137279887, 0.34488624379210969), mean=0.063631947008012474, variance=0.0052880103481552747, skewness=1.2028593489784434, kurtosis=1.8546682074632503)
# #######################################
# #######################################
# Low length 30
# Top length 30
# #######################################
# #######################################
# Low break:  False
# #######################################
# Top break:  False
# ####################################
# ####---> Signals (Phase 3) <---#####
# Buy: -0.282747369023
# ####################################
# Sell: 0.222736802814
# ####################################
# Current status
# ####################################
# Status 0.353460224908
# ####################################
# Current status
# ####################################
# Current stop_loss 6769.3331
# ####################################
